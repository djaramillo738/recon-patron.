# %% [markdown]
# # TALLER 1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## EJERCICIO 1

# %% [markdown]
# ### a

# %%
#Cargamos el dataset.
college=pd.read_csv("data/College.csv")

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56
# 2   53        66       12.9           30    8735         54
# 3   92        97        7.7           37   19016         59
# 4   76        72       11.9            2   10922         15

# %% [markdown]
# ### b

# %%
#cambiamos el nombre de la primera columna del dataset a lo que se pide.
college.rename(columns={'Unnamed: 0': 'college'}, inplace=True)

# %%
college.head()
# Out:
#                         college Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56
# 2   53        66       12.9           30    8735         54
# 3   92        97        7.7           37   19016         59
# 4   76        72       11.9            2   10922         15

# %% [markdown]
# ### c

# %% [markdown]
# #### i

# %%
#summary
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# min      139.000000      1.000000   2340.000000  1780.000000    96.000000
# 25%      992.000000     95.000000   7320.000000  3597.000000   470.000000
# 50%     1707.000000    353.000000   9990.000000  4200.000000   500.000000
# 75%     4005.000000    967.000000  12925.000000  5050.000000   600.000000
# max    31643.000000  21836.000000  21700.000000  8124.000000  2340.000000
#
#           Personal         PhD    Terminal   S.F.Ratio  perc.alumni  \
# count   777.000000  777.000000  777.000000  777.000000   777.000000
# mean   1340.642214   72.660232   79.702703   14.089704    22.743887
# std     677.071454   16.328155   14.722359    3.958349    12.391801
# min     250.000000    8.000000   24.000000    2.500000     0.000000
# 25%     850.000000   62.000000   71.000000   11.500000    13.000000
# 50%    1200.000000   75.000000   82.000000   13.600000    21.000000
# 75%    1700.000000   85.000000   92.000000   16.500000    31.000000
# max    6800.000000  103.000000  100.000000   39.800000    64.000000
#
#              Expend  Grad.Rate
# count    777.000000  777.00000
# mean    9660.171171   65.46332
# std     5221.768440   17.17771
# min     3186.000000   10.00000
# 25%     6751.000000   53.00000
# 50%     8377.000000   65.00000
# 75%    10830.000000   78.00000
# max    56233.000000  118.00000

# %% [markdown]
# #### ii

# %%
#importamos lo que necesitamos para pintar
from pandas.tools.plotting import scatter_matrix

# %%
#Seleccionamos las columnas que necesitamos
df=college[college.columns[1:11]]

# %%
#permitimos que matplotlib pinte en el notebook
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
plt.show()

# %% [markdown]
# #### iii

# %%
college.head()
# Out:
#                         college Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56
# 2   53        66       12.9           30    8735         54
# 3   92        97        7.7           37   19016         59
# 4   76        72       11.9            2   10922         15

# %%
#Importamos lo que necesitamos para pintar
import plotly.offline as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
#Permitimos que plotly pinte en el notebook
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#Seleccionamos los datos a pintar
si=college[college['Private']=='Yes']
no=college[college['Private']=='No']

# %%
trace0 = go.Box(
    y=si['Outstate'],
    name = 'Private',
    marker = dict(
        color = 'rgb(214, 12, 140)',
    )
)
trace1 = go.Box(
    y=no['Outstate'],
    name = 'Public',
    marker = dict(
        color = 'rgb(0, 128, 128)',
    )
)
layout = go.Layout(
    title = "Boxplots Outstate y Private"
)
data = [trace0, trace1]
fig = go.Figure(data=data,layout=layout)
py.iplot(data)
# Out:
# <div id="131f5265-d6be-49e4-9d5c-62067558700f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("131f5265-d6be-49e4-9d5c-62067558700f", [{"y": [7440, 12280, 11250, 12960, 7560, 13500, 13290, 13868, 15595, 10468, 16548, 17080, 9690, 12572, 8352, 8700, 19760, 10100, 9996, 15476, 11208, 8644, 12000, 11902, 13353, 10990, 11280, 9925, 8620, 10995, 9690, 19264, 17926, 11290, 6450, 12850, 8840, 9000, 7800, 16304, 9550, 21700, 13800, 8050, 8740, 8540, 6200, 5188, 11660, 6500, 7150, 9900, 18420, 19030, 14080, 10870, 19380, 9592, 4371, 10260, 10265, 2340, 19528, 18165, 18550, 13306, 13130, 10518, 8900, 12950, 10230, 7550, 6060, 10750, 13050, 8400, 19292, 17900, 12200, 8150, 13125, 15700, 9270, 13712, 9384, 14340, 7344, 11400, 8950, 11230, 10938, 8300, 11850, 16624, 13500, 10335, 8730, 9300, 4412, 17000, 17500, 10740, 15960, 13925, 9888, 18930, 19510, 10860, 9800, 11790, 12600, 11180, 12247, 12224, 10900, 9990, 11138, 8300, 11844, 18000, 16240, 17142, 8294, 10425, 18624, 10500, 6900, 10800, 9216, 18740, 12050, 15248, 10628, 8000, 6230, 8920, 9130, 12292, 19545, 17295, 10850, 16900, 14300, 18700, 6700, 9570, 8310, 9800, 9000, 13420, 18432, 8730, 18590, 15036, 4950, 11190, 9650, 8770, 15360, 14190, 14990, 11800, 9100, 7800, 8578, 17600, 10485, 10955, 15000, 9400, 5120, 13900, 8025, 8390, 14235, 9650, 10390, 13320, 5500, 9900, 13440, 10970, 8180, 9476, 12500, 17450, 8100, 18300, 9150, 19964, 6120, 13000, 12200, 9420, 15588, 8958, 9100, 11750, 8330, 10310, 15688, 5224, 13404, 14125, 11000, 19700, 13252, 13218, 7161, 8200, 6300, 5504, 17480, 18485, 17230, 9376, 8800, 11090, 14067, 19029, 11600, 13470, 13960, 12275, 9990, 8080, 9950, 7260, 7800, 10500, 8050, 14550, 14360, 10000, 8840, 9210, 10690, 14424, 7620, 6398, 11700, 18800
#Vamos a crear la columna Elite

college['Elite']=['No' for x in range(len(college)) ]

# %%
#Ahora reemplazamos los No por Yes si se cumple Top10perc>50
for x in range(len(college)):
    if college['Top10perc'][x]>50:
        college.set_value(x, 'Elite', 'Yes')

# %%
#Vemos cuantas universidades son de la élite
college['Elite'].describe()
# Out:
# count     777
# unique      2
# top        No
# freq      699
# Name: Elite, dtype: object

# %%
#Seleccionamos los datos a pintar
si_e=college[college['Elite']=='Yes']
no_e=college[college['Elite']=='No']

# %%
#Pintamos
trace0 = go.Box(
    y=si_e['Outstate'],
    name = 'Elite',
    marker = dict(
        color = 'rgb(214, 12, 140)',
    )
)
trace1 = go.Box(
    y=no_e['Outstate'],
    name = 'No Elite',
    marker = dict(
        color = 'rgb(0, 128, 128)',
    )
)
layout = go.Layout(
    title = "Boxplots Outstate y Elite"
)
data = [trace0, trace1]
fig = go.Figure(data=data,layout=layout)
py.iplot(data)
# Out:
# <div id="d0dd0036-3596-4240-8156-b2f48c239c51" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d0dd0036-3596-4240-8156-b2f48c239c51", [{"y": [12960, 19760, 17926, 11660, 19030, 19528, 18165, 19292, 17900, 15700, 11850, 17000, 18930, 18000, 11720, 17142, 18624, 19545, 17295, 18432, 18590, 17600, 9900, 13440, 18300, 6489, 15688, 5224, 18485, 17230, 8800, 14360, 18800, 15909, 20100, 17748, 10320, 16404, 16560, 12900, 18200, 16200, 19900, 17475, 15200, 19300, 17238, 18820, 16900, 6550, 6550, 10900, 5391, 12240, 11648, 12024, 18930, 7090, 7560, 15732, 9843, 8400, 16850, 17020, 16230, 17840, 12212, 17865, 18920, 13850, 13750, 18350, 18345, 19130, 11480, 19629, 12680, 19840], "name": "Elite", "type": "box", "marker": {"color": "rgb(214, 12, 140)"}}, {"y": [7440, 12280, 11250, 7560, 13500, 13290, 13868, 15595, 10468, 16548, 17080, 9690, 12572, 8352, 8700, 10100, 9996, 5130, 15476, 6806, 11208, 7434, 8644, 3460, 12000, 6300, 11902, 13353, 10990, 11280, 9925, 8620, 10995, 9690, 19264, 11290, 6450, 12850, 8840, 9000, 7800, 16304, 4425, 9550, 21700, 13800, 8050, 8740, 8540, 6200, 5188, 6500, 7844, 7150, 9900, 18420, 7452, 14080, 10870, 19380, 9592, 4371, 10260, 10265, 2340, 18550, 13306, 13130, 10518, 8900, 12950, 7380, 7706, 10230, 7550, 6060, 10750, 13050, 8400, 12200, 8150, 13125, 7656, 9270, 13712, 9384, 14340, 7344, 11400, 8950, 11230, 10938, 5962, 4620, 7242, 8300, 16624, 13500, 10335, 8730, 9300, 7860, 4412, 17500, 10740, 15960, 8116, 7168, 13925, 9888, 19510, 10860, 6120, 9800, 11790, 12600, 11180, 12247, 12224, 10900, 9990, 11138, 8300, 11844, 16240, 8412, 8294, 10425, 10500, 6900, 10800, 9216, 18740, 12050, 15248, 10628, 8000, 6230, 8920, 9130, 12292, 10850, 4528, 16900, 14300, 18700, 4486, 6700, 9570, 8310, 9800, 9000, 13420, 8730, 15036, 7248, 5800, 4950, 11190, 5962, 5710, 9650, 8770, 15360, 14190, 14990, 11800, 9100, 7800, 8578, 5401, 10485, 10955, 6297, 15000, 6806, 9400, 5120, 13900, 6597, 8025, 6680, 8390, 14235, 6198, 5840, 9650, 10390, 13320, 5500, 10970, 8180, 9476, 12500, 10800, 17450, 8100, 6744, 9150, 19964, 6120, 13000, 12200, 9420, 15588, 8958, 9100, 6108, 11750, 8330, 10310, 13404, 14125, 11000, 19700, 13252, 13218, 7161, 8200, 6300, 5504, 17480, 9376, 11090, 14067, 19029, 11600, 13470, 13960, 12275, 9990, 8080, 9950, 7260, 7800, 10500, 8050, 14550, 7799, 10000, 8840, 6892, 9766, 9210, 10690, 7550, 14424, 7994, 7620, 3946, 6398, 11700, 7656, 9414, 14850, 6995, 8400, 7870, 8000, 19240, 9600, 10910, 8664, 15747, 8842, 12600, 18730, 6987, 16880, 9400, 4752, 5170, 4938, 17163, 11040, 13850, 18700, 10100, 11700, 8840, 15800, 10560, 5950, 4818, 9200, 13380, 4400, 7352, 7920, 11200, 5150, 5925, 3957, 12990, 13592, 11100, 11500, 13240, 13900, 12450, 7320, 9620, 9858, 10440, 12370, 14700, 4300, 9400, 13850, 10700, 11610, 5094, 11200, 6490, 11510, 10200, 11390, 11200, 9250, 11040, 4486, 7680, 6930, 7950, 11985, 9813, 6720, 12500, 5016, 10300, 8856, 10658, 8127, 6840, 7844, 8200, 11910, 11320, 11505, 5580, 9866, 4386, 3840, 8550, 13000, 12480, 6073, 5552, 3648, 8438, 4426, 14990, 7050, 10520, 4515, 19300, 6844, 8950, 10500, 9900, 12850, 7470, 12474, 12250, 7400, 16975, 4738, 13240, 9090, 10850, 8832, 5376, 10194, 5542, 6806, 8400, 8242, 11718, 5834, 12580, 4856, 13380, 6746, 7799, 3735, 9840, 9900, 14134, 9990, 9114, 19670, 15990, 7629, 16732, 5390, 6400, 5336, 12888, 6530, 8530, 11000, 13312, 11925, 14210, 6360, 10645, 2580, 8640, 11690, 10500, 5640, 6000, 17688, 10178, 9700, 4290, 11859, 14400, 9556, 11020, 10100, 12030, 6684, 4449, 13840, 13970, 19960, 12700, 13250, 15200, 9870, 13425, 9490, 8734, 12520, 16425, 10950, 4356, 7410, 7411, 7410, 11070, 10450, 12950, 4259, 8670, 10880, 12247, 11200, 9985, 12750, 12200, 11690, 12730, 10800, 10300, 13030, 14350, 9408, 10850, 10860, 10575, 10475, 5130, 8236, 8384, 13584, 8325, 8955, 12669, 128 ...

# %% [markdown]
# ### Conclusión 2

# %% [markdown]
# Para estudiantes de afuera del estado, estudiar en una universidad cara (del tercer cuartil hacia arriba) de la élite no vale mucho más que una cara que no sea de la élite.

# %% [markdown]
# #### v

# %%
college.head()
# Out:
#                         college Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate Elite
# 0   70        78       18.1           12    7041         60    No
# 1   29        30       12.2           16   10527         56    No
# 2   53        66       12.9           30    8735         54    No
# 3   92        97        7.7           37   19016         59   Yes
# 4   76        72       11.9            2   10922         15    No

# %%
#Escogemos las variables cuantitativas
histos=college[['Apps', 'Accept', 'Top25perc', 'PhD', 'Expend']]

# %%
import matplotlib.pyplot as plt

# %%
#Pintemos ahora con matplotlib...
#Primero con 10 bins
fig = plt.figure()

ax1 = fig.add_subplot(231)
ax1.hist(histos['Apps']/1000,  10, color='#0b8590', alpha=0.5)
ax1.set_title('Apps en miles')


ax2 = fig.add_subplot(232)
ax2.hist(histos['Accept']/1000,  10, color='#116163', alpha=0.5)
ax2.set_title('Accept en miles')

ax3 = fig.add_subplot(233)
ax3.hist(histos['Top25perc'],  10, color='#0d274d', alpha=0.5)
ax3.set_title('Top25perc')

ax4 = fig.add_subplot(234)
ax4.hist(histos['PhD'],  10, color='#6cb5bc', alpha=0.5)
ax4.set_title('PhD')

ax5 = fig.add_subplot(235)
ax5.hist(histos['Expend']/1000,  10, color='#2ec2a3', alpha=0.5)
ax5.set_title('Expend en miles')

plt.tight_layout()
fig = plt.gcf()

# %%
#28 bins
fig = plt.figure()

ax1 = fig.add_subplot(231)
ax1.hist(histos['Apps']/1000,  28, color='#0b8590', alpha=0.5)
ax1.set_title('Apps en miles')


ax2 = fig.add_subplot(232)
ax2.hist(histos['Accept']/1000,  28, color='#116163', alpha=0.5)
ax2.set_title('Accept en miles')

ax3 = fig.add_subplot(233)
ax3.hist(histos['Top25perc'],  28, color='#0d274d', alpha=0.5)
ax3.set_title('Top25perc')

ax4 = fig.add_subplot(234)
ax4.hist(histos['PhD'],  28, color='#6cb5bc', alpha=0.5)
ax4.set_title('PhD')

ax5 = fig.add_subplot(235)
ax5.hist(histos['Expend']/1000,  28, color='#2ec2a3', alpha=0.5)
ax5.set_title('Expend en miles')

plt.tight_layout()
fig = plt.gcf()

# %%
#40 bins
fig = plt.figure()

ax1 = fig.add_subplot(231)
ax1.hist(histos['Apps']/1000,  40, color='#0b8590', alpha=0.5)
ax1.set_title('Apps en miles')


ax2 = fig.add_subplot(232)
ax2.hist(histos['Accept']/1000,  40, color='#116163', alpha=0.5)
ax2.set_title('Accept en miles')

ax3 = fig.add_subplot(233)
ax3.hist(histos['Top25perc'],  40, color='#0d274d', alpha=0.5)
ax3.set_title('Top25perc')

ax4 = fig.add_subplot(234)
ax4.hist(histos['PhD'],  40, color='#6cb5bc', alpha=0.5)
ax4.set_title('PhD')

ax5 = fig.add_subplot(235)
ax5.hist(histos['Expend']/1000,  40, color='#2ec2a3', alpha=0.5)
ax5.set_title('Expend en miles')

plt.tight_layout()
fig = plt.gcf()

# %% [markdown]
# ### Observación

# %% [markdown]
# Dado que 28 es más o menos la raíz del número de datos, es para el número de bins que mejor se ve la distribución de los datos.

# %% [markdown]
# #### vi

# %% [markdown]
# Vamos a atacar cuatro situaciones:
#     1. Entender los outliers del item iii.
#     2. Ver si es más difícil entrar a las universidades públicas o       privadas.
#     3. Determinar si los Top10perc de sus clases van más a universidades públicas o privadas.
#     4. Ver si es estadísticamente más probable graduarse de universidades públicas o privadas.

# %%
#1.
#Primero seleccionemos las universidades públicas
publicas=college[college['Private']=='No']

# %%
publicas.head()
# Out:
#                                  college Private   Apps  Accept  Enroll  \
# 19               Angelo State University      No   3540    2001    1016
# 21          Appalachian State University      No   7313    4664    1910
# 23  Arizona State University Main campus      No  12809   10308    3761
# 25              Arkansas Tech University      No   1734    1729     951
# 27         Auburn University-Main Campus      No   7548    6791    3070
#
#     Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  \
# 19         24         54         4190         1512      5130        3592
# 21         20         63         9940         1035      6806        2540
# 23         24         49        22593         7585      7434        4850
# 25         12         52         3602          939      3460        2650
# 27         25         57        16262         1716      6300        3933
#
#     Books  Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate  \
# 19    500      2000   60        62       23.1            5    4010         34
# 21     96      2000   83        96       18.3           14    5854         70
# 23    700      2100   88        93       18.9            5    4602         48
# 25    450      1000   57        60       19.6            5    4739         48
# 27    600      1908   85        91       16.7           18    6642         69
#
#    Elite
# 19    No
# 21    No
# 23    No
# 25    No
# 27    No

# %%
#Ahora cojamos los features que necesitamos
publicas_temp=publicas[['Outstate', 'Elite']]

# %%
#Finalmente los outliers...
outliers_publicas=publicas_temp[publicas_temp['Outstate']>np.percentile(publicas_temp['Outstate'],q=75)]

# %% [markdown]
# Veamos si quizá son más caras porque son de la élite...

# %%
#Importemos el paquete para contar elementos
from scipy.stats import itemfreq

# %%
itemfreq(outliers_publicas['Elite'])
# Out:
# array([['No', 43],
#        ['Yes', 7]], dtype=object)

# %%
itemfreq(publicas['Elite'])
# Out:
# array([['No', 199],
#        ['Yes', 13]], dtype=object)

# %% [markdown]
# ### Conclusión 3

# %% [markdown]
# Más de la mitad de los outliers son de la élite

# %%
#Ataquemos ahora el item 2.
college['perc accept']=100*college['Accept']/college['Apps']

# %%
publicas=college[college['Private']=='No']
privadas=college[college['Private']=='Yes']

# %%
#Analicemos por boxplots...

trace0 = go.Box(
    y=privadas['perc accept'],
    name = 'Privadas',
    marker = dict(
        color = 'rgb(0, 128, 128)',
    )
)
trace1 = go.Box(
    y=publicas['perc accept'],
    name = 'Publicas',
    marker = dict(
        color = 'rgb(214, 12, 140)',
    )
)
layout = go.Layout(
    title = "Boxplots tasa aceptación privadas y públicas"
)
data = [trace0, trace1]
fig = go.Figure(data=data,layout=layout)
py.iplot(data)
# Out:
# <div id="1d5fcc2a-1312-44c9-869f-d444ce2a6259" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1d5fcc2a-1312-44c9-869f-d444ce2a6259", [{"y": [74.21686746987952, 88.01463860933211, 76.82072829131653, 83.69304556354916, 75.64766839378238, 81.60136286201022, 96.3172804532578, 90.57398630858347, 80.82851637764932, 85.56701030927834, 82.27482678983834, 71.64404223227753, 66.15776081424936, 85.24072612470403, 63.36032388663968, 76.97183098591549, 23.05904230590423, 74.67105263157895, 62.30088495575221, 92.70687237026648, 83.36025848142165, 47.175141242937855, 79.62529274004685, 77.49244712990937, 88.23842469398616, 95.26938239159001, 84.17721518987342, 88.6762360446571, 80.23255813953489, 80.82840236686391, 73.5632183908046, 43.87434554973822, 56.169871794871796, 79.1919191919192, 88.04938271604938, 73.08684436801376, 87.6084262701363, 78.16455696202532, 79.8360655737705, 69.92424242424242, 98.10126582278481, 63.005780346820806, 67.22446624350837, 65.71582346609257, 92.9384965831435, 91.08910891089108, 76.49402390438247, 69.86634264884569, 73.04347826086956, 67.2, 94.96021220159152, 74.27745664739885, 64.41660063391443, 30.363528009535163, 74.49209932279909, 90.62914786302098, 65.527950310559, 74.65940054495913, 85.51532033426184, 89.54081632653062, 80.31026252983294, 73.346911065852, 25.734943588113776, 55.2901023890785, 58.231521075137444, 80.0, 86.24047417442846
 66, 85, 40, 78, 72, 88, 45, 67, 59, 73, 79, 97, 90, 61, 67, 53, 46, 98, 36, 64, 50, 43, 60, 39, 70, 65, 91, 96, 78, 93, 74, 52, 65, 64, 88, 57, 90, 63, 93, 75, 67, 51, 45, 77, 66, 69, 47, 59, 52, 64, 97, 93, 72, 63, 100, 80, 66, 62, 92, 68, 89, 62, 57, 65, 82, 47, 78, 79, 68, 95, 83, 90, 96, 30, 68, 73, 58, 72, 75, 89, 68, 63, 67, 86, 90, 65, 90, 63, 90, 48, 91, 69, 64, 84, 92, 67, 60, 59, 62, 80, 50, 85, 71, 72, 72, 52, 80, 63, 67, 68, 59, 52, 99, 67, 91, 50, 78, 75, 82, 83, 49, 99, 99], "name": "Privadas", "type": "box", "marker": {"color": "rgb(0, 128, 128)"}}, {"y": [34, 70, 48, 48, 69, 46, 75, 67, 59, 61, 79, 49, 50, 51, 48, 73, 46, 51, 93, 59, 58, 46, 58, 42, 50, 76, 50, 68, 24, 66, 58, 46, 43, 46, 70, 34, 57, 54, 40, 68, 65, 98, 26, 36, 54, 61, 26, 51, 45, 63, 62, 37, 45, 51, 68, 84, 51, 59, 85, 71, 65, 71, 53, 63, 100, 74, 37, 58, 60, 52, 72, 34, 57, 44, 62, 42, 76, 41, 56, 54, 53, 64, 48, 48, 63, 44, 35, 67, 62, 47, 51, 77, 57, 58, 58, 56, 41, 72, 67, 45, 53, 43, 56, 51, 63, 64, 74, 80, 56, 57, 49, 63, 42, 53, 66, 76, 53, 65, 59, 46, 69, 43, 10, 84, 81, 56, 33, 39, 78, 66, 46, 54, 71, 66, 63, 54, 81, 34, 57, 31, 59, 64, 35, 55, 63, 68, 56, 87, 53, 51, 45, 53, 58, 49, 48, 51, 53, 75, 37, 83, 62, 53, 55, 49, 47, 35, 40, 77, 44, 54, 66, 63, 43, 48, 63, 47, 36, 38, 45, 53, 29, 65, 50, 37, 79, 95, 65, 53, 65, 36, 67, 46, 72, 38, 45, 40, 45, 31, 73, 56, 52, 52, 60, 55, 55, 52, 61, 65, 87, 58, 59, 40], "name": "Publicas", "type": "box", "marker": {"color": "rgb(214, 12, 140)"}}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### Conclusión 6

# %% [markdown]
# En promedio se gradúan más en las privadas que en las públicas (¿quizá tenga que ver el hecho de que ellos mismos pagan toda la matrícula sin subsidio estatal?).
#
# Sin embargo hay unas universidades privadas cuyas tasas son muy bajas; esto hace sentido pues existen unas a las cuales es difícil entrar y consecuentemente debería ser difícil mantenerse y luego graduarse.

# %% [markdown]
# ## EJERCICIO 2

# %%
#Cargamos la data
auto=pd.read_csv('data/Auto.csv')

# %%
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### (a)

# %% [markdown]
# Cuantitativos=mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin.
# Cualitativos=name.

# %%
#Seleccionemos los features cuantitativos
cuanti=auto.iloc[:,0:7]

# %%
#Antes de proceder limpiemos los datos...
for col in cuanti.columns:
    for i in range(len(cuanti)):
        try:
            auto.set_value(i,col,float(auto[col][i]))
        except:
            auto.set_value(i, col, np.NaN)
auto=auto.dropna(how="any") 

#Debemos volver horsepower a número real
auto['horsepower']=[float(x) for x in auto['horsepower']]

# %%
auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cuanti=auto.iloc[:,0:7]

# %%
cuanti.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70

# %% [markdown]
# ### (b)

# %%
for col in cuanti.columns:
    print("rango de "+str(col)+"=", [min(auto[col]), max(auto[col])])
# Out:
# rango de mpg= [9.0, 46.600000000000001]
# rango de cylinders= [3, 8]
# rango de displacement= [68.0, 455.0]
# rango de horsepower= [46.0, 230.0]
# rango de weight= [1613, 5140]
# rango de acceleration= [8.0, 24.800000000000001]
# rango de year= [70, 82]

# %% [markdown]
# ### (c)

# %%
for col in cuanti.columns:
    print("media de "+str(col)+"=", np.mean(auto[col]))
    print("std de "+str(col)+"=", np.std(auto[col]))
# Out:
# media de mpg= 23.44591836734694
# std de mpg= 7.795045762682584
# media de cylinders= 5.471938775510204
# std de cylinders= 1.703606114150195
# media de displacement= 194.41198979591837
# std de displacement= 104.51044418133284
# media de horsepower= 104.46938775510205
# std de horsepower= 38.442032714425984
# media de weight= 2977.5841836734694
# std de weight= 848.3184465698364
# media de acceleration= 15.541326530612228
# std de acceleration= 2.7553429127509963
# media de year= 75.9795918367347
# std de year= 3.679034899615175

# %% [markdown]
# ### (d)

# %%
#Primero eliminamos de la fila 10 a la 85...
auto_nuevo=cuanti.drop(auto.index[10:85])

# %%
for col in auto_nuevo.columns:
    print("media nueva de "+str(col)+"=", np.mean(auto_nuevo[col]))
    print("std nueva de "+str(col)+"=", np.std(auto_nuevo[col]))
# Out:
# media nueva de mpg= 24.37476340694006
# std nueva de mpg= 7.860137440955561
# media nueva de cylinders= 5.381703470031546
# std nueva de cylinders= 1.655517379007591
# media nueva de displacement= 187.8801261829653
# std nueva de displacement= 100.01185173924225
# media nueva de horsepower= 101.0031545741325
# std nueva de horsepower= 35.9463759770665
# media nueva de weight= 2938.8548895899053
# std nueva de weight= 810.359466377351
# media nueva de acceleration= 15.704100946372236
# std nueva de acceleration= 2.7156194248223184
# media nueva de year= 77.1230283911672
# std nueva de year= 3.1222221181443723

# %% [markdown]
# ### (e)

# %%
#Para anlizar los datos hacemos scatter plots de las continuas 
#y boxplots para las discretas



#iniciamos por las continuas
scatter_matrix(cuanti[['mpg', 'horsepower', 'displacement', 'weight', 'acceleration']], alpha=0.5, diagonal='kde')
plt.show()

# %% [markdown]
# ### Conclusión 1

# %%
#Calculamos aquí los coeficientes de correlación para hablar con cifras.
import scipy.stats
scipy.stats.spearmanr(cuanti[['weight', 'horsepower', 'displacement', 'mpg', 'acceleration']])
# Out:
# SpearmanrResult(correlation=array([[ 1.        ,  0.87881933,  0.9456304 , -0.87558512, -0.40510867],
#        [ 0.87881933,  1.        ,  0.87617079, -0.8536164 , -0.6581423 ],
#        [ 0.9456304 ,  0.87617079,  1.        , -0.85523359, -0.49940336],
#        [-0.87558512, -0.8536164 , -0.85523359,  1.        ,  0.44153886],
#        [-0.40510867, -0.6581423 , -0.49940336,  0.44153886,  1.        ]]), pvalue=array([[  0.00000000e+000,   2.18267354e-127,   2.46317012e-192,
#           2.66237794e-125,   6.48424635e-017],
#        [  2.18267354e-127,   0.00000000e+000,   1.12673685e-125,
#           1.61938325e-112,   5.15784037e-050],
#        [  2.46317012e-192,   1.12673685e-125,   0.00000000e+000,
#           2.19577760e-113,   4.06120964e-026],
#        [  2.66237794e-125,   1.61938325e-112,   2.19577760e-113,
#           0.00000000e+000,   3.90360357e-020],
#        [  6.48424635e-017,   5.15784037e-050,   4.06120964e-026,
#           3.90360357e-020,   0.00000000e+000]]))

# %% [markdown]
# Hay una relación inversa muy similar entre mpg vs. displacement,mpg vs horsepower y mpg vs. weight. Esta semejanza se explica en la casi que perfecta relación entre weight y displacement (un factor de 0.93) y la alta entre horsepower y estas dos.
#
# Entre el resto de variables no se envidencia relación fuerte.

# %%
#Ahora veamos las discretas. Convertiremos todas las variables discretas
#a 3 o menos categorias para visualizar mejor. Para ello definamos
#algunas funciones auxiliares.
def convertidor_hp(x):
    if x <= np.percentile(cuanti['horsepower'], q=33):
        return 0
    elif (x>np.percentile(cuanti['horsepower'], q=33)) & (x <= np.percentile(cuanti['horsepower'], q=66)):
        return 1
    else:
        return 2

def convertidor_year(x):
    if x <= np.percentile(cuanti['year'], q=33):
        return 0
    elif (x>np.percentile(cuanti['year'], q=33)) & (x <= np.percentile(cuanti['year'], q=66)):
        return 1
    else:
        return 2
        
def convertidor_cylinder(x):
    if x <= np.percentile(cuanti['cylinders'], q=33):
        return 0
    elif (x>np.percentile(cuanti['cylinders'], q=33)) & (x <= np.percentile(cuanti['cylinders'], q=66)):
        return 1
    else:
        return 2

# %%
#APlicamos las funciones a las tres variables
cuanti['cat_hp']=[convertidor_hp(x) for x in cuanti['horsepower']]
cuanti['cat_year']=[convertidor_year(x) for x in cuanti['year']]
cuanti['cat_cylinder']=[convertidor_cylinder(x) for x in cuanti['cylinders']]

#DEfinamos los subsets que vamos a pintar
hp1=cuanti[cuanti['cat_hp']==0]
hp2=cuanti[cuanti['cat_hp']==1]
hp3=cuanti[cuanti['cat_hp']==2]

year1=cuanti[cuanti['cat_year']==0]
year2=cuanti[cuanti['cat_year']==1]
year3=cuanti[cuanti['cat_year']==2]

cy1=cuanti[cuanti['cat_cylinder']==0]
cy2=cuanti[cuanti['cat_cylinder']==1]
cy3=cuanti[cuanti['cat_cylinder']==2]

# %% [markdown]
# #### Displacement vs. HP

# %%
trace1 = go.Box(
    y=hp1['displacement'],
    name = 'HP BAJO',
    marker = dict(
        color = '#9932cc',
    )
)
trace2 = go.Box(
    y=hp2['displacement'],
    name = 'HP MEDIO',
    marker = dict(
        color = '#ff00ff',
    )
)
trace3 = go.Box(
    y=hp3['displacement'],
    name = 'HP ALTO',
    marker = dict(
        color = '#0000cd',
    )
)
layout = go.Layout(
    title = "Boxplots HP vs. Displacement",
    
    yaxis=dict(
        title='Displacement',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)
data = [trace1, trace2, trace3]
fig = go.Figure(data=data,layout=layout)
py.iplot(data)
# Out:
# <div id="04231590-c131-413a-a4aa-62ea0514a448" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
"type": "box", "marker": {"color": "#0000cd"}}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
prom_hp_year1=np.mean(year1['horsepower'])
prom_hp_year2=np.mean(year2['horsepower'])
prom_hp_year3=np.mean(year3['horsepower'])

prom_cy_year1=np.mean(year1['cylinders'])
prom_cy_year2=np.mean(year2['cylinders'])
prom_cy_year3=np.mean(year3['cylinders'])

# %%
print([prom_hp_year1, prom_hp_year2, prom_hp_year3], [prom_cy_year1, prom_cy_year2, prom_cy_year3])
# Out:
# [121.40666666666667, 101.5703125, 85.43859649122807] [6.013333333333334, 5.515625, 4.7105263157894735]

# %% [markdown]
# ### Conclusión 2

# %% [markdown]
# El displacement está relacionado positivamente con el número de cilindros y los caballos de fuerza.
#
# Cabe notar también que la gráfica del displacement vs. el año (más los promedios de caballos de fuerza y número de cilindros vs. año) muestra como el número de cilindros y los caballos de fuerza han venido disminuyendo con los años.

# %% [markdown]
# #### mpg vs. horsepower

# %%
trace1 = go.Box(
    y=hp1['mpg'],
    name = 'HP BAJO',
    marker = dict(
        color = '#9932cc',
    )
)
trace2 = go.Box(
    y=hp2['mpg'],
    name = 'HP MEDIO',
    marker = dict(
        color = '#ff00ff',
    )
)
trace3 = go.Box(
    y=hp3['mpg'],
    name = 'HP ALTO',
    marker = dict(
        color = '#0000cd',
    )
)
layout = go.Layout(
    title = "Boxplots HP vs. mpg",
    
    yaxis=dict(
        title='mpg',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)
data = [trace1, trace2, trace3]
fig = go.Figure(data=data,layout=layout)
py.iplot(data)
# Out:
# <div id="12feff92-dc4f-46d4-b5a7-f1c891ea3f8a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("12feff92-dc4f-46d4-b5a7-f1c891ea3f8a", [{"y": [26.0, 22.0, 30.0, 30.0, 31.0, 35.0, 27.0, 26.0, 25.0, 23.0, 22.0, 26.0, 28.0, 26.0, 21.0, 29.0, 24.0, 31.0, 26.0, 32.0, 25.0, 29.0, 26.0, 26.0, 31.0, 32.0, 28.0, 24.0, 26.0, 31.0, 15.0, 15.0, 29.0, 23.0, 23.0, 25.0, 29.0, 33.0, 25.0, 26.0, 27.0, 24.0, 29.0, 24.5, 29.0, 33.0, 18.0, 29.5, 32.0, 28.0, 26.5, 31.5, 30.0, 36.0, 33.5, 29.0, 26.0, 30.5, 33.5, 30.0, 30.5, 43.1, 36.1, 32.8, 39.4, 36.1, 30.0, 30.9, 31.5, 29.5, 31.9, 34.1, 35.7, 27.4, 25.4, 27.2, 34.2, 34.5, 31.8, 37.3, 41.5, 38.1, 32.1, 37.2, 34.3, 31.3, 32.2, 46.6, 40.8, 44.3, 43.4, 36.4, 30.0, 44.6, 33.8, 29.8, 32.4, 27.2, 26.6, 30.0, 39.1, 39.0, 35.1, 32.3, 37.0, 37.7, 34.1, 34.7, 34.4, 29.9, 33.0, 33.7, 32.4, 31.6, 28.1, 30.7, 29.0, 36.0, 37.0, 31.0, 38.0, 36.0, 36.0, 34.0, 38.0, 32.0, 38.0, 36.0, 44.0, 32.0, 28.0, 31.0], "name": "HP BAJO", "type": "box", "marker": {"color": "#9932cc"}}, {"y":
 18.0, 18.5, 17.5, 19.0, 16.5, 17.5, 20.5, 19.0, 18.5, 22.0, 19.2, 20.5, 20.2, 20.5, 19.4, 20.6, 20.8, 18.6, 18.1, 17.7, 20.3, 17.0, 16.2, 21.5, 19.8, 20.2, 20.6, 25.4, 28.8, 26.8, 19.1, 36.4, 32.7, 23.5, 30.7, 25.4, 24.2, 22.4, 20.2, 17.6, 25.0, 38.0, 22.0], "name": "CANTIDAD NORMAL DE CILINDROS", "type": "box", "marker": {"color": "#ff00ff"}}, {"y": [18.0, 15.0, 18.0, 16.0, 17.0, 15.0, 14.0, 14.0, 14.0, 15.0, 15.0, 14.0, 15.0, 14.0, 10.0, 10.0, 11.0, 9.0, 14.0, 14.0, 14.0, 14.0, 12.0, 13.0, 13.0, 13.0, 14.0, 15.0, 14.0, 17.0, 11.0, 13.0, 12.0, 13.0, 15.0, 13.0, 13.0, 14.0, 13.0, 14.0, 13.0, 14.0, 15.0, 12.0, 13.0, 13.0, 14.0, 13.0, 12.0, 13.0, 11.0, 12.0, 13.0, 12.0, 15.0, 16.0, 15.0, 11.0, 16.0, 13.0, 14.0, 14.0, 14.0, 16.0, 15.0, 16.0, 14.0, 20.0, 13.0, 17.5, 16.0, 15.5, 14.5, 13.0, 16.5, 13.0, 13.0, 13.0, 17.5, 17.0, 15.5, 15.0, 16.0, 15.5, 15.5, 16.0, 19.9, 19.4, 20.2, 19.2, 18.1, 17.5, 17.0, 17.6, 16.5, 18.2, 16.9, 15.5, 19.2, 18.5, 23.0, 23.9, 26.6], "name": "MUCHOS CILINDROS", "type": "box", "marker": {"color": "#0000cd"}}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### Observación 1

# %% [markdown]
# No se percibe nada que ya no supiéramos ya.

# %% [markdown]
# ### (e)

# %% [markdown]
# De la matriz de correlación de Spearman usada en el inciso anterior vemos que la mejor variable para predecir mpg sería weight. En segundo lugar está Displacement y por último horsepower no lo haría mal tampoco.

# %% [markdown]
# ## EJERCICIO 3 (CAPÍTULO 2 EJERCICIO 10)

# %% [markdown]
# ## (a)

# %%
#Carguemos los datos
from sklearn.datasets import load_boston
boston_tmp = load_boston()
boston = pd.DataFrame(boston_tmp.data, columns= boston_tmp.feature_names)
boston['target']=boston_tmp.target
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
boston.shape
# Out:
# (506, 14)

# %% [markdown]
# Hay 506 filas. Cada fila es una localidad de Boston.

# %% [markdown]
# ### (b)

# %%
boston_sin_target=boston.drop('target', axis=1)
boston_cuanti_sin_target=boston_sin_target.drop('CHAS', axis=1)

# %%
plt.figure(figsize=(12,12))
scatter_matrix(boston_cuanti_sin_target, alpha=0.5, diagonal='kde' )
plt.show()

# %% [markdown]
# A priori pareciera que:
# 1. Hay relación cuadrática negativa entre DIS-NOX.
# 2. Hay relación lineal negativa entre ZN-INDUS.
# 3. Hay relación lineal positiva entre ZN-RM
#
# 4. ZN-RAD y B-INDUS son independientes entre si.

# %% [markdown]
# ### (c)

# %%
#importemos lo que necesitamos(pintaremos con seaborn y necesitamos
#normalizar para visualizar mejor.)
import seaborn as sns
from sklearn import preprocessing

# %%
for col in boston_cuanti_sin_target:
    boston_cuanti_sin_target[col]=preprocessing.scale(boston_cuanti_sin_target[col])

# %%
# Compute the correlation matrix
corr = boston_cuanti_sin_target.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr
# Out:
#              CRIM        ZN     INDUS       NOX        RM       AGE       DIS  \
# CRIM     1.000000 -0.199458  0.404471  0.417521 -0.219940  0.350784 -0.377904
# ZN      -0.199458  1.000000 -0.533828 -0.516604  0.311991 -0.569537  0.664408
# INDUS    0.404471 -0.533828  1.000000  0.763651 -0.391676  0.644779 -0.708027
# NOX      0.417521 -0.516604  0.763651  1.000000 -0.302188  0.731470 -0.769230
# RM      -0.219940  0.311991 -0.391676 -0.302188  1.000000 -0.240265  0.205246
# AGE      0.350784 -0.569537  0.644779  0.731470 -0.240265  1.000000 -0.747881
# DIS     -0.377904  0.664408 -0.708027 -0.769230  0.205246 -0.747881  1.000000
# RAD      0.622029 -0.311948  0.595129  0.611441 -0.209847  0.456022 -0.494588
# TAX      0.579564 -0.314563  0.720760  0.668023 -0.292048  0.506456 -0.534432
# PTRATIO  0.288250 -0.391679  0.383248  0.188933 -0.355501  0.261515 -0.232471
# B       -0.377365  0.175520 -0.356977 -0.380051  0.128069 -0.273534  0.291512
# LSTAT    0.452220 -0.412995  0.603800  0.590879 -0.613808  0.602339 -0.496996
#
#               RAD       TAX   PTRATIO         B     LSTAT
# CRIM     0.622029  0.579564  0.288250 -0.377365  0.452220
# ZN      -0.311948 -0.314563 -0.391679  0.175520 -0.412995
# INDUS    0.595129  0.720760  0.383248 -0.356977  0.603800
# NOX      0.611441  0.668023  0.188933 -0.380051  0.590879
# RM      -0.209847 -0.292048 -0.355501  0.128069 -0.613808
# AGE      0.456022  0.506456  0.261515 -0.273534  0.602339
# DIS     -0.494588 -0.534432 -0.232471  0.291512 -0.496996
# RAD      1.000000  0.910228  0.464741 -0.444413  0.488676
# TAX      0.910228  1.000000  0.460853 -0.441808  0.543993
# PTRATIO  0.464741  0.460853  1.000000 -0.177383  0.374044
# B       -0.444413 -0.441808 -0.177383  1.000000 -0.366087
# LSTAT    0.488676  0.543993  0.374044 -0.366087  1.000000

# %% [markdown]
# ## Conclusión 1

# %% [markdown]
# A pesar que con ninguna variable evidencia fuerte relación con CRIM, podríamos decir que tanto RAD como TAX se relacionan en cierta medida de manera positiva.

# %%
trace1 = go.Box(
    y=boston_cuanti_sin_target['CRIM'],
    name = 'CRIM',
    marker = dict(
        color = '#9932cc',
    )
)
trace2 = go.Box(
    y=boston_cuanti_sin_target['TAX'],
    name = 'TAX',
    marker = dict(
        color = '#ff00ff',
    )
)
trace3 = go.Box(
    y=boston_cuanti_sin_target['PTRATIO'],
    name = 'PTRATIO',
    marker = dict(
        color = '#0000cd',
    )
)
layout = go.Layout(
    title = "Boxplots boston",
    
    yaxis=dict(
        title='mpg',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)
data = [trace1, trace2, trace3]
fig = go.Figure(data=data,layout=layout)
py.iplot(data)
# Out:
# <div id="b8a8f419-75c5-4cdd-8de8-b5251b2a419b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b8a8f419-75c5-4cdd-8de8-b5251b2a419b", [{"y": [-0.41771335233133905, -0.4152693249673689, -0.41527165372140795, -0.41468015019549237, -0.41040921528789703, -0.4149735732044111, -0.40816895390234265, -0.40161816879052936, -0.39385293844735786, -0.3986501717677757, -0.3922635638157146, -0.4047713017593865, -0.4075297109186268, -0.3451214314264531, -0.34416664227044763, -0.3453973887800791, -0.29573205138952013, -0.3271387927370033, -0.3249835308738738, -0.33393875453099364, -0.27269368768131935, -0.31923965903658713, -0.2749432640830298, -0.3033587208673689, -0.33109068834125044, -0.3205786926090339, -0.34021358228918097, -0.3071615762131176, -0.328444059375884, -0.3017262642860034, -0.2867803208634589, -0.2607087550194114, -0.25683487267547195, -0.2843456085156449, -0.2306561841456287, -0.4109774312734223, -0.40710354
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 398  38.3518  0.0   18.1   0.0  0.693  5.453  100.0  1.4896  24.0  666.0
# 405  67.9208  0.0   18.1   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
#
#      PTRATIO       B  LSTAT  target
# 398     20.2  396.90  30.59     5.0
# 405     20.2  384.97  22.98     5.0

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT      target
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# Los CRIM son altísimos!! Muuuy superior al 75% de los datos. Estas dos eran dos de los outliers que vimos en los boxplots arriba.
#
# También son los que más lejos están de centros de Boston.
#
# Para el resto están con el tercer cuantil menos para DIS que están debajo del primer cuantil.

# %%
print(len(boston[boston['RM']>7]), len(boston[boston['RM']>8]))
# Out:
# 64 13

# %%
x = boston.loc[:,'RM'] > 8
print(boston[x])
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 97   0.12083   0.0   2.89   0.0  0.4450  8.069  76.0  3.4952   2.0  276.0
# 163  1.51902   0.0  19.58   1.0  0.6050  8.375  93.9  2.1620   5.0  403.0
# 204  0.02009  95.0   2.68   0.0  0.4161  8.034  31.9  5.1180   4.0  224.0
# 224  0.31533   0.0   6.20   0.0  0.5040  8.266  78.3  2.8944   8.0  307.0
# 225  0.52693   0.0   6.20   0.0  0.5040  8.725  83.0  2.8944   8.0  307.0
# 226  0.38214   0.0   6.20   0.0  0.5040  8.040  86.5  3.2157   8.0  307.0
# 232  0.57529   0.0   6.20   0.0  0.5070  8.337  73.3  3.8384   8.0  307.0
# 233  0.33147   0.0   6.20   0.0  0.5070  8.247  70.4  3.6519   8.0  307.0
# 253  0.36894  22.0   5.86   0.0  0.4310  8.259   8.4  8.9067   7.0  330.0
# 257  0.61154  20.0   3.97   0.0  0.6470  8.704  86.9  1.8010   5.0  264.0
# 262  0.52014  20.0   3.97   0.0  0.6470  8.398  91.5  2.2885   5.0  264.0
# 267  0.57834  20.0   3.97   0.0  0.5750  8.297  67.0  2.4216   5.0  264.0
# 364  3.47428   0.0  18.10   1.0  0.7180  8.780  82.9  1.9047  24.0  666.0
#
#      PTRATIO       B  LSTAT  target
# 97      18.0  396.90   4.21    38.7
# 163     14.7  388.45   3.32    50.0
# 204     14.7  390.55   2.88    50.0
# 224     17.4  385.05   4.14    44.8
# 225     17.4  382.00   4.63    50.0
# 226     17.4  387.38   3.13    37.6
# 232     17.4  385.91   2.47    41.7
# 233     17.4  378.95   3.95    48.3
# 253     19.1  396.90   3.54    42.8
# 257     13.0  389.70   5.12    50.0
# 262     13.0  386.86   5.91    48.8
# 267     13.0  384.54   7.44    50.0
# 364     20.2  354.55   5.29    21.9

# %% [markdown]
# Son las de target más alto!

# %% [markdown]
# ## EJERCICIO 4 (CAPÍTULO 3 EJERCICIO 8)

# %% [markdown]
# ### (a)

# %%
#Importamos lo que necesitamos
from sklearn.linear_model import LinearRegression

# %%
#Inicializamos
lm=LinearRegression()

# %%
#Creamos las muestras de test y train
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(cuanti['horsepower'], cuanti['mpg'], test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (313,) (313,)
# (79,) (79,)

# %%
lm.fit(X_train.reshape(-1,1), y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Veamos los coeficientes...
print(lm.coef_, lm.intercept_)
# Out:
# [-0.16120158] 40.2832435042

# %%
#VEamos que tan bueno es nuestro modelo
lm.score(X_test.reshape(-1,1), y_test)
# Out:
# 0.56791191919498984

# %% [markdown]
# ### Observación 1

# %% [markdown]
# El score (R^2) no es tan bueno pues un sólo feature no suele ser suficiente para hacer una buena predicción de otro.

# %%
plt.scatter(cuanti['horsepower'], cuanti['mpg'], alpha=0.5, c='#aed3f4')
plt.title('Regresión lineal horsepower vs. mpg')
plt.plot(X_test, lm.predict(X_test.reshape(-1,1)), alpha=0.8, c='#3c1033')

# %% [markdown]
# #### (i)

# %% [markdown]
# Si hay relación.

# %% [markdown]
# #### (ii)

# %% [markdown]
# Se percibe una relación, más sin embargo sería apresurado (y de hecho equivocado) afirmar que sea lineal.

# %% [markdown]
# #### (iii)

# %% [markdown]
# Negativo.

# %% [markdown]
# #### (iv)

# %%
lm.predict(98)
# Out:
# array([ 24.48548868])

# %%
[lm.predict(np.percentile(cuanti['horsepower'], q=97.5)), lm.predict(np.percentile(cuanti['horsepower'], q=2.5))]
# Out:
# [array([ 7.7527647]), array([ 31.77583013])]

# %% [markdown]
# ### (b)

# %%
import statsmodels.api as sm

# %%
#Agreguemos la constante a X para poder hacer un producto punto
y=cuanti['mpg']
X=cuanti['horsepower'].reshape(-1,1)
X=sm.add_constant(X)

# %%
#Inicialicemos el modelo
est=sm.OLS(y,X.astype(float))

# %%
est=est.fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           7.03e-81
# Time:                        16:12:01   Log-Likelihood:                -1178.7
# No. Observations:                 392   AIC:                             2361.
# Df Residuals:                     390   BIC:                             2369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         39.9359      0.717     55.660      0.000        38.525    41.347
# x1            -0.1578      0.006    -24.489      0.000        -0.171    -0.145
# ==============================================================================
# Omnibus:                       16.432   Durbin-Watson:                   0.920
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.305
# Skew:                           0.492   Prob(JB):                     0.000175
# Kurtosis:                       3.299   Cond. No.                         322.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Definamos los datos que usamos para pintar la recta
X_tmp = np.linspace(X.min(), X.max(), 100)[:, np.newaxis]
X_tmp = sm.add_constant(X_tmp)
y_hat = est.predict(X_tmp)

#Pintemos  la recta
plt.scatter(X[:,1], y, alpha=0.3)  # Plot the raw data
plt.xlabel("Horsepower")
plt.ylabel("mpg")
plt.plot(X_tmp[:, 1], y_hat, 'r', alpha=0.9)  # Add the regression line, colored in red

# %% [markdown]
# ### (c)

# %%
#Definamos los datos que usamos para pintar la recta
X_tmp = np.linspace(X.min(), X.max(), 100)[:, np.newaxis]
X_tmp = sm.add_constant(X_tmp)
y_hat = est.predict(X_tmp)

#Pintemos  la recta
plt.scatter(X[:,1], y, alpha=0.3)  # Plot the raw data
plt.title('Mínimos cuadrados lineal horsepower vs. mpg')
plt.xlabel("Horsepower")
plt.ylabel("mpg")
plt.plot(X_tmp[:, 1], y_hat, c='#e18af5', alpha=0.9)  # Add the regression line, colored in red

# %% [markdown]
# Para valores extremos el modelo no es preciso.

# %% [markdown]
# ## EJERCICIO 5 (CAPÍTULO 3 EJERCICIO 9)

# %% [markdown]
# ### (a)

# %%
auto['horsepower']=[float(x) for x in auto['horsepower']]

# %%
plt.figure(figsize=(20,20))
scatter_matrix(auto.iloc[:,0:8], alpha=0.5, diagonal='kde')
plt.show()

# %% [markdown]
# ### (b)

# %%
#importemos lo que necesitamos(íntaremos con seaborn)
import seaborn as sns

# %%
# Compute the correlation matrix
corr = auto.iloc[:,0:8].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### (c)

# %%
X_train, X_test, y_train, y_test = train_test_split(cuanti[['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']], cuanti['mpg'], test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (313, 6) (313,)
# (79, 6) (79,)

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Veamos los coeficientes...
print(lm.coef_, lm.intercept_)
# Out:
# [ -2.43992994e-01   5.18582541e-03   5.77680065e-04  -6.74713714e-03
#    1.22930927e-01   7.51174688e-01] -15.0671682479

# %%
#Veamos que tan bueno es nuestro modelo
lm.score(X_test, y_test)
# Out:
# 0.80183173085308757

# %% [markdown]
# #### (i)

# %% [markdown]
# La relación es mucho más fuerte ahora que cuando solo usábamos horsepower. Tenemos un Score de 0.83 (antes era de 0.5)

# %% [markdown]
# #### (ii)

# %% [markdown]
# year (2.84)
# acceleration (0.91)
# cylinders (0.55)

# %% [markdown]
# #### (iii)

# %% [markdown]
# Es la que mejor prediciría mpg ella sola

# %% [markdown]
# ### (d)

# %% [markdown]
# ### (e)

# %% [markdown]
# ### (f)

# %%
cuanti.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    cat_hp  cat_year  cat_cylinder
# 0       2         0             2
# 1       2         0             2
# 2       2         0             2
# 3       2         0             2
# 4       2         0             2

# %%
cuanti_tmp=cuanti[['mpg', 'cylinders', 'horsepower', 'weight', 'acceleration', 'year']]

# %%
cuanti_tmp_log=cuanti_tmp.applymap(np.log)
cuanti_tmp_sqrt=cuanti_tmp.applymap(np.sqrt)
cuanti_tmp_sqr=cuanti_tmp.applymap(np.square)

# %%
#Scatters para los
plt.figure(figsize=(20,20))
scatter_matrix(cuanti_tmp_log, alpha=0.5, diagonal='kde')
plt.show()

# %% [markdown]
# ### Conclusión 1

# %% [markdown]
# Dado que log(horsepower) y log(weight) parecen tener una relación lineal, concluimos que la relaciónm ya evidenciada entre horsepower y weight era lineal en sus logaritmos.

# %%
#Scatters para los
plt.figure(figsize=(20,20))
scatter_matrix(cuanti_tmp_sqrt, alpha=0.5, diagonal='kde')
plt.show()

# %%
cuanti_tmp_sqrt#Scatters para los
plt.figure(figsize=(20,20))
scatter_matrix(cuanti_tmp_sqr, alpha=0.5, diagonal='kde')
plt.show()

# %% [markdown]
# Se confirma la conclusión 1.

# %% [markdown]
# ## EJERCICIO 6 (CAPÍTULO 3 EJERCICIO 10)

# %% [markdown]
# ### (a)

# %%
carseats=pd.read_csv('data/Carseats.csv')

# %%
carseats.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
#Convirtamos las categoricas a numero
carseats['Urban_cat']=pd.Categorical(carseats['Urban']).codes
carseats['US_cat']=pd.Categorical(carseats['US']).codes

# %%
carseats.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US  Urban_cat  US_cat
# 0         17   Yes  Yes          1       1
# 1         10   Yes  Yes          1       1
# 2         12   Yes  Yes          1       1
# 3         14   Yes  Yes          1       1
# 4         13   Yes   No          1       0

# %%
#Dividamos las muestras para entrenar y testear el modelo
X_train, X_test, y_train, y_test = train_test_split(carseats[['Price', 'Urban_cat', 'US_cat']], carseats['Sales'], test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (320, 3) (320,)
# (80, 3) (80,)

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#VEamos que tal lo hace nuestro modelo
lm.score(X_test, y_test)
# Out:
# 0.03738676955172815

# %%
#Veamos los resultados...
print(lm.coef_, lm.intercept_)
# Out:
# [-0.06025289 -0.03316986  1.16789749] 13.7199000662

# %% [markdown]
# ### (b)

# %% [markdown]
# La única variable que influye fuertemente en Sales es US.

# %% [markdown]
# ### (c)

# %% [markdown]
# Sales = Price*-0.0545+Urban_cat*-0.0318+US_cat*1.113+13.065

# %% [markdown]
# donde,
# Urban_cat=1 si Urban='Yes' y 0 en caso contrario
# US_cat=1 si US='Yes' y 0 en caso contrario

# %% [markdown]
# ### (d)

# %%
#Scikit-learn no tiene implementado las pruebas de hipótesis. 
#Por ese motivo, lo hacemos con stats models...
import statsmodels.formula.api as smf

# %%
lm1=smf.ols(formula='Sales~Price+Urban_cat+US_cat', data=carseats).fit()

# %%
# veamos los parámetros
lm1.params
# Out:
# Intercept    13.043469
# Price        -0.054459
# Urban_cat    -0.021916
# US_cat        1.200573
# dtype: float64

# %%
lm1.pvalues
# Out:
# Intercept    3.626602e-62
# Price        1.609917e-22
# Urban_cat    9.357389e-01
# US_cat       4.860245e-06
# dtype: float64

# %% [markdown]
# Solamente para Urban

# %% [markdown]
# ### (e)

# %%
#Dividamos las muestras para entrenar y testear el modelo
X_train, X_test, y_train, y_test = train_test_split(carseats['Urban_cat'], carseats['Sales'], test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (320,) (320,)
# (80,) (80,)

# %%
lm.fit(X_train.reshape(-1,1), y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.score(X_test.reshape(-1,1), y_test)
# Out:
# -0.0033836181083228833

# %% [markdown]
# ### (f)

# %% [markdown]
# Dentro de lo malos que son ambos modelos, el último es muchísimo peor.

# %% [markdown]
# ### (g)

# %%
lm2=smf.ols(formula='Sales~Urban_cat', data=carseats).fit()
lm2.conf_int()
# Out:
#                   0         1
# Intercept  7.051871  8.075248
# Urban_cat -0.704780  0.514044

# %% [markdown]
# ### (h)

# %%
#Ataquemos el problema con boxplots
ur0=carseats[carseats['Urban_cat']==0]
ur1=carseats[carseats['Urban_cat']==1]

# %%
trace1 = go.Box(
    y=ur0['Sales'],
    name = 'US=0',
    marker = dict(
        color = '#9932cc',
    )
)
trace2 = go.Box(
    y=ur1['Sales'],
    name = 'US=1',
    marker = dict(
        color = '#ff00ff',
    )
)

layout = go.Layout(
    title = "Boxplots Cylinders vs. mpg",
    
    yaxis=dict(
        title='mpg',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)
data = [trace1, trace2,]
fig = go.Figure(data=data,layout=layout)
py.iplot(data)
# Out:
# <div id="eec5db07-c165-4bc0-b822-dec30cbfda38" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("eec5db07-c165-4bc0-b822-dec30cbfda38", [{"y": [10.81, 6.54, 4.69, 9.01, 8.71, 13.91, 12.13, 14.9, 8.33, 6.2, 11.07, 8.89, 3.24, 2.07, 12.44, 4.9, 7.32, 7.8, 4.9, 6.5, 12.61, 6.2, 8.55, 7.7, 2.23, 8.47, 11.7, 7.95, 5.33, 9.48, 12.49, 4.88, 4.11, 5.3, 0.16, 8.98, 5.08, 8.19, 9.34, 4.47, 6.44, 5.17, 12.3, 9.09, 10.51, 7.56, 10.49, 10.77, 7.64, 5.93, 6.89, 10.21, 12.53, 9.32, 4.67, 2.93, 5.68, 8.22, 0.0, 5.61, 10.66, 9.95, 8.68, 12.11, 8.79, 7.56, 5.56, 4.1, 8.19, 3.02, 4.36, 4.34, 4.1, 5.4, 11.19, 5.16, 8.09, 8.65, 9.43, 4
}}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# Dada la naturaleza discreta de US, no habrán high leverage más sin embargo en el plot de arriba se evidencian outliers cuando US="Yes".

# %% [markdown]
# ## EJERCICIO 7 (CAPÍTULO 3 EJERCICIO 11)

# %%
import random
np.random.seed(1)

# %% [markdown]
# ### (a)

# %%
x0=np.random.randn(100)
y0=2*x0+np.random.randn(100)

# %%
lm2=smf.ols(formula='y~x+0', data=pd.DataFrame({'x': x0, 'y': y0})).fit()
lm2.conf_int()
# Out:
#           0         1
# x  1.895531  2.317952

# %%
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.796
# Method:                 Least Squares   F-statistic:                     391.7
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           3.46e-36
# Time:                        16:12:17   Log-Likelihood:                -135.67
# No. Observations:                 100   AIC:                             273.3
# Df Residuals:                      99   BIC:                             275.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x              2.1067      0.106     19.792      0.000         1.896     2.318
# ==============================================================================
# Omnibus:                        0.880   Durbin-Watson:                   2.106
# Prob(Omnibus):                  0.644   Jarque-Bera (JB):                0.554
# Skew:                          -0.172   Prob(JB):                        0.758
# Kurtosis:                       3.119   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Por la generación aleatroia de los datos tiene sentido que tengamos un R squared tan malo.

# %% [markdown]
# ### (b)

# %%
lm2=smf.ols(formula='x~y+0', data=pd.DataFrame({'x': x0, 'y': y0})).fit()
lm2.conf_int()
# Out:
#           0         1
# y  0.340918  0.416891

# %%
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      x   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.796
# Method:                 Least Squares   F-statistic:                     391.7
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           3.46e-36
# Time:                        16:12:17   Log-Likelihood:                -49.891
# No. Observations:                 100   AIC:                             101.8
# Df Residuals:                      99   BIC:                             104.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# y              0.3789      0.019     19.792      0.000         0.341     0.417
# ==============================================================================
# Omnibus:                        0.476   Durbin-Watson:                   2.166
# Prob(Omnibus):                  0.788   Jarque-Bera (JB):                0.631
# Skew:                           0.115   Prob(JB):                        0.729
# Kurtosis:                       2.685   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Por la generación aleatroia de los datos tiene sentido que tengamos un R squared tan malo.

# %% [markdown]
# ### (c)

# %% [markdown]
# El t-statistic es el mismo y por ende el pvalue también.

# %% [markdown]
# ### (d)

# %% [markdown]
# \begin{equation*}
# (\frac{\beta}{SE(\beta)})^2=\frac{(\sum{x_iy_i})^2(n-1)\sum{x_i^2}}{(\sum{x_i^2})^2\sum{(y_i-x_i\beta)^2}}=\frac{(n-1)(\sum{x_iy_i})^2}{\sum{x_i^2}\sum{y_i^2}-(\sum{x_iy_i})^2}
# \end{equation*}
#
# \begin{equation*}
# \Leftrightarrow \sum{x_i^2}\sum{(y_i-x_i\beta)^2} = \sum{x_i^2}\sum{y_i^2}-(\sum{x_iy_i})^2
# \end{equation*}
#
#
# \begin{equation*}
# \Leftrightarrow  \sum{x_i^2}\sum{y_i^2}-2\sum{x_i^2}\frac{\sum{x_iy_i}}{\sum{x_i^2}}\sum{x_iy_i}+\sum{x_i^2}\frac{(\sum{x_iy_i})^2}{(\sum{x_i^2})^2}\sum{x_i^2}=\sum{x_i^2}\sum{y_i^2}-(\sum{x_iy_i})^2
# \end{equation*}
#
#
# \begin{equation*}
# \Leftrightarrow \sum{x_i^2}\sum{y_i^2}-2(\sum{x_iy_i})^2+(\sum{x_iy_i})^2=\sum{x_i^2}\sum{y_i^2}-(\sum{x_iy_i})^2
# \end{equation*}

# %% [markdown]
# ### (e)

# %% [markdown]
# Es porque la fórmula que se obtuvo en el inciso anterior es simétrica para x, y.

# %% [markdown]
# ### (f)

# %%
lm2=smf.ols(formula='y~x', data=pd.DataFrame({'x': x0, 'y': y0})).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.798
# Method:                 Least Squares   F-statistic:                     391.4
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           5.39e-36
# Time:                        16:12:17   Log-Likelihood:                -134.44
# No. Observations:                 100   AIC:                             272.9
# Df Residuals:                      98   BIC:                             278.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.1470      0.094      1.564      0.121        -0.039     0.334
# x              2.0954      0.106     19.783      0.000         1.885     2.306
# ==============================================================================
# Omnibus:                        0.898   Durbin-Watson:                   2.157
# Prob(Omnibus):                  0.638   Jarque-Bera (JB):                0.561
# Skew:                          -0.172   Prob(JB):                        0.755
# Kurtosis:                       3.127   Cond. No.                         1.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='x~y', data=pd.DataFrame({'x': x0, 'y': y0})).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      x   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.798
# Method:                 Least Squares   F-statistic:                     391.4
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           5.39e-36
# Time:                        16:12:17   Log-Likelihood:                -49.289
# No. Observations:                 100   AIC:                             102.6
# Df Residuals:                      98   BIC:                             107.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.0440      0.040     -1.090      0.279        -0.124     0.036
# y              0.3817      0.019     19.783      0.000         0.343     0.420
# ==============================================================================
# Omnibus:                        0.456   Durbin-Watson:                   2.192
# Prob(Omnibus):                  0.796   Jarque-Bera (JB):                0.611
# Skew:                           0.118   Prob(JB):                        0.737
# Kurtosis:                       2.698   Cond. No.                         2.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## EJERCICIO 8 (CAPÍTULO 3 EJERCICIO 12)

# %% [markdown]
# ### (a)

# %% [markdown]
# Necesitamos que las sumas de los cuadrados de cada muestra sean iguales.

# %% [markdown]
# ### (b)

# %%
x0=np.random.normal(0,1, 100)
y0=np.random.normal(0,0.25, 100)

# %%
suma_prod=sum(x0*y0)
cuadrados_x=sum(x0*x0)
cuadrados_y=sum(y0*y0)

# %%
suma_prod, cuadrados_x, cuadrados_y
# Out:
# (-1.412715169282541, 100.99938653454016, 7.0836631077561965)

# %%
b_x=suma_prod/cuadrados_x
b_y=suma_prod/cuadrados_y
print(b_x,b_y)
# Out:
# -0.0139873638619 -0.199432856672

# %%
lm2=smf.ols(formula='x~y+0', data=pd.DataFrame({'x': x0, 'y': y0})).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      x   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.2769
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):              0.600
# Time:                        16:12:17   Log-Likelihood:                -142.25
# No. Observations:                 100   AIC:                             286.5
# Df Residuals:                      99   BIC:                             289.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# y             -0.1994      0.379     -0.526      0.600        -0.951     0.553
# ==============================================================================
# Omnibus:                        0.381   Durbin-Watson:                   2.209
# Prob(Omnibus):                  0.826   Jarque-Bera (JB):                0.472
# Skew:                           0.139   Prob(JB):                        0.790
# Kurtosis:                       2.812   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='y~x+0', data=pd.DataFrame({'x': x0, 'y': y0})).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.2769
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):              0.600
# Time:                        16:12:17   Log-Likelihood:                -9.3852
# No. Observations:                 100   AIC:                             20.77
# Df Residuals:                      99   BIC:                             23.38
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x             -0.0140      0.027     -0.526      0.600        -0.067     0.039
# ==============================================================================
# Omnibus:                        0.426   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.808   Jarque-Bera (JB):                0.121
# Skew:                          -0.045   Prob(JB):                        0.941
# Kurtosis:                       3.145   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### (c)

# %%
x0=np.random.normal(0,1, 100)
y0=-x0

# %% [markdown]
# ## EJERCICIO 9 (CAPÍTULO 3 EJERCICIO 13)

# %%
random.seed(1)

# %% [markdown]
# ### (a)

# %%
x=np.random.normal(0,1,100)

# %% [markdown]
# ### (b)

# %%
eps=np.random.normal(0,0.25,100)

# %% [markdown]
# ### (c)

# %%
y=-1+0.5*x+eps

# %%
len(y)
# Out:
# 100

# %%
print(-1,0.5)
# Out:
# -1 0.5

# %% [markdown]
# ### (d)

# %%
plt.scatter(x,y,alpha=0.5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter x vs. y')
plt.show()

# %% [markdown]
# Se percibe una relación lineal entre las variables.

# %% [markdown]
# ### (e)

# %%
#Recuerde que la regresion lineal de scikit.learn usa mínimos cuadrados

#Dividamos las muestras para entrenar y testear el modelo
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (80,) (80,)
# (20,) (20,)

# %%
lm.fit(X_train.reshape(-1,1), y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.score(X_test.reshape(-1,1), y_test)
# Out:
# 0.90595761448895706

# %%
print(lm.intercept_, lm.coef_)
# Out:
# -1.03428470284 [ 0.51668738]

# %% [markdown]
# Se aproxima demasiado bien!!!

# %% [markdown]
# ### (f)

# %%
#Definamos los datos que usamos para pintar la recta
x_tmp = np.linspace(x.min(), x.max(), 100)[:, np.newaxis]
x_tmp = sm.add_constant(x_tmp)
y_hat = lm.predict(x_tmp.reshape(-1,1))

#Pintemos  la recta
plt.scatter(x, y, alpha=0.3)
plt.xlabel("x")
plt.ylabel("y")
plt.title('Scatter y regresión')
plt.plot(x_tmp.reshape(-1,1), y_hat, label='Regresión lineal por mínimos cuadrados', c='#cc99cc', alpha=0.9)
plt.legend()
plt.show()

# %% [markdown]
# ### (g)

# %%
coef=np.polyfit(x,y,2)
coef
# Out:
# array([-0.00948914,  0.52828448, -1.0074661 ])

# %%
p=np.poly1d(coef)
plt.scatter(x, y, alpha=0.3)
plt.plot(x_tmp.reshape(-1,1), y_hat, label='lineal', c='#cc99cc', alpha=0.9)
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x,p(x), c='#00a9ff', label='cuadrática')
plt.title('Lineal vs. cuadrática')
plt.legend()
plt.show()

# %% [markdown]
# La mejora es tan poca que no se alcanza a distinguir la regresión lineal de la cuadrática.

# %% [markdown]
# ### (h) e (i)

# %%
#Generamos el ruido
eps_h=np.random.normal(0,0.1,100)
eps_i=np.random.normal(0,0.8, 100)

#Generamos las respectivas variables objetivo
y_h=-1+0.5*x+eps_h
y_i=-1+0.5*x+eps_i


print(len(y_h), len(y_i))
# Out:
# 100 100

# %%
#Dividamos las muestras para entrenar y testear el modelo
X_train, X_test, y_train, y_test = train_test_split(x, y_h, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (80,) (80,)
# (20,) (20,)

# %%
#Definamos los datos que usamos para pintar la recta
lm.fit(X_train.reshape(-1,1), y_train)
x_tmp = np.linspace(x.min(), x.max(), 100)[:, np.newaxis]
x_tmp = sm.add_constant(x_tmp)
y_hat = lm.predict(x_tmp.reshape(-1,1))

#Pintemos
plt.scatter(x,y_h,alpha=0.5)
plt.xlabel('x')
plt.ylabel('y_h')
plt.plot(x_tmp.reshape(-1,1), y_hat, label='Regresión lineal por mínimos cuadrados', c='#cc99cc', alpha=0.9)
plt.title('Scatter x vs. y_h')
plt.show()

# %% [markdown]
# A pesar del buen fit del modelo veamos su score...

# %%
lm.score(X_test.reshape(-1,1), y_test)
# Out:
# 0.97076190680266727

# %% [markdown]
# Increíble

# %%
#Dividamos las muestras para entrenar y testear el modelo
X_train, X_test, y_train, y_test = train_test_split(x, y_i, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (80,) (80,)
# (20,) (20,)

# %%
#Definamos los datos que usamos para pintar la recta
lm.fit(X_train.reshape(-1,1), y_train)
x_tmp = np.linspace(x.min(), x.max(), 100)[:, np.newaxis]
x_tmp = sm.add_constant(x_tmp)
y_hat = lm.predict(x_tmp.reshape(-1,1))

plt.scatter(x,y_i,alpha=0.5)
plt.xlabel('x')
plt.ylabel('y_i')
plt.plot(x_tmp.reshape(-1,1), y_hat, label='Regresión lineal por mínimos cuadrados', c='#cc99cc', alpha=0.9)
plt.title('Scatter x vs. y_i')
plt.show()

# %%
lm.score(X_test.reshape(-1,1), y_test)
# Out:
# 0.27645282522351922

# %% [markdown]
# Al tener un error con alta varianza la aproximación del modelo deja de ser buena y el score disminuye dramáticamente.

# %% [markdown]
# ### (j)

# %%
lm2=smf.ols(formula='y~x', data=pd.DataFrame({'x': x, 'y': y, 'z': eps})).fit()

# %%
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     513.2
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           9.76e-41
# Time:                        16:12:18   Log-Likelihood:                 1.3012
# No. Observations:                 100   AIC:                             1.398
# Df Residuals:                      98   BIC:                             6.608
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -1.0174      0.024    -41.867      0.000        -1.066    -0.969
# x              0.5242      0.023     22.654      0.000         0.478     0.570
# ==============================================================================
# Omnibus:                        0.207   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.902   Jarque-Bera (JB):                0.331
# Skew:                          -0.097   Prob(JB):                        0.848
# Kurtosis:                       2.796   Cond. No.                         1.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='y~x', data=pd.DataFrame({'x': x, 'y': y_h, 'z': eps_h})).fit()

# %%
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     2813.
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           5.52e-74
# Time:                        16:12:18   Log-Likelihood:                 94.412
# No. Observations:                 100   AIC:                            -184.8
# Df Residuals:                      98   BIC:                            -179.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.9987      0.010   -104.279      0.000        -1.018    -0.980
# x              0.4837      0.009     53.041      0.000         0.466     0.502
# ==============================================================================
# Omnibus:                        2.817   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.245   Jarque-Bera (JB):                2.634
# Skew:                          -0.321   Prob(JB):                        0.268
# Kurtosis:                       2.531   Cond. No.                         1.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='y~x', data=pd.DataFrame({'x': x, 'y': y_i, 'z': eps_i})).fit()

# %%
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.331
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     48.51
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           3.80e-10
# Time:                        16:12:18   Log-Likelihood:                -120.61
# No. Observations:                 100   AIC:                             245.2
# Df Residuals:                      98   BIC:                             250.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.9322      0.082    -11.335      0.000        -1.095    -0.769
# x              0.5454      0.078      6.965      0.000         0.390     0.701
# ==============================================================================
# Omnibus:                        0.926   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.629   Jarque-Bera (JB):                0.908
# Skew:                          -0.027   Prob(JB):                        0.635
# Kurtosis:                       2.536   Cond. No.                         1.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# El ancho de los intervalos viene de acuerdo a la varianza

# %% [markdown]
# ## EJERCICIO 10 (CAPÍTULO 3 EJERCICIO 14)

# %% [markdown]
# ### (a)

# %%
random.seed(1)

# %%
x1=np.random.uniform(0,1,100)
x2=0.5*x1+np.random.normal(0,1,100)/10
y=2+2*x1+0.3*x2+np.random.normal(0,1,100)

# %%
print(2,2,0.3)
# Out:
# 2 2 0.3

# %% [markdown]
# ### (b)

# %%
np.corrcoef(x1,x2)
# Out:
# array([[ 1.       ,  0.8374908],
#        [ 0.8374908,  1.       ]])

# %%
plt.scatter(x1,x2, alpha=0.5, c='#4a1f3d')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# ### (c)

# %%
lm2=smf.ols(formula='y~x+z', data=pd.DataFrame({'x': x1, 'z': x2, 'y': y})).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.274
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                     18.29
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           1.82e-07
# Time:                        16:12:19   Log-Likelihood:                -145.15
# No. Observations:                 100   AIC:                             296.3
# Df Residuals:                      97   BIC:                             304.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.0654      0.226      9.154      0.000         1.618     2.513
# x              1.8453      0.685      2.694      0.008         0.486     3.204
# z              0.7070      1.007      0.702      0.484        -1.291     2.705
# ==============================================================================
# Omnibus:                        0.887   Durbin-Watson:                   2.310
# Prob(Omnibus):                  0.642   Jarque-Bera (JB):                0.970
# Skew:                          -0.138   Prob(JB):                        0.616
# Kurtosis:                       2.605   Cond. No.                         13.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Para x2 rechazamos la hiótesis nula.
#
# El coeficiente verdadero de x1 está lejos del que estima el modelo. Eso era de esperarse pues fue generado con distribución uniforme y y con una normal.

# %% [markdown]
# ### (d)

# %%
lm2=smf.ols(formula='y~x', data=pd.DataFrame({'x': x1, 'z': x2, 'y': y})).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.270
# Model:                            OLS   Adj. R-squared:                  0.263
# Method:                 Least Squares   F-statistic:                     36.27
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           3.00e-08
# Time:                        16:12:19   Log-Likelihood:                -145.40
# No. Observations:                 100   AIC:                             294.8
# Df Residuals:                      98   BIC:                             300.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.0282      0.219      9.271      0.000         1.594     2.462
# x              2.2481      0.373      6.023      0.000         1.507     2.989
# ==============================================================================
# Omnibus:                        0.798   Durbin-Watson:                   2.318
# Prob(Omnibus):                  0.671   Jarque-Bera (JB):                0.884
# Skew:                          -0.112   Prob(JB):                        0.643
# Kurtosis:                       2.598   Cond. No.                         4.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Rechazamos la hipótesis nula

# %% [markdown]
# ### (e)

# %%
lm2=smf.ols(formula='y~z', data=pd.DataFrame({'x': x1, 'z': x2, 'y': y})).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.212
# Method:                 Least Squares   F-statistic:                     27.56
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           8.84e-07
# Time:                        16:12:19   Log-Likelihood:                -148.76
# No. Observations:                 100   AIC:                             301.5
# Df Residuals:                      98   BIC:                             306.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.4686      0.174     14.170      0.000         2.123     2.814
# z              2.9787      0.567      5.250      0.000         1.853     4.105
# ==============================================================================
# Omnibus:                        2.548   Durbin-Watson:                   2.250
# Prob(Omnibus):                  0.280   Jarque-Bera (JB):                2.041
# Skew:                          -0.208   Prob(JB):                        0.360
# Kurtosis:                       2.437   Cond. No.                         5.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Rechazamos la hiótesis nula

# %% [markdown]
# ### (f)

# %% [markdown]
# No hay contradicción; lo que pasa es que el peso del error en y no se puede controlar por x_2.

# %% [markdown]
# ### (g)

# %%
x1=np.insert(x1, obj=-1, values=0.1)
x2=np.insert(x2, obj=-1, values=0.8)
y=np.insert(y, obj=-1, values=6)
print(len(x1), len(x2), len(y))
# Out:
# 101 101 101

# %%
lm2=smf.ols(formula='y~x+z', data=pd.DataFrame({'x': x1, 'z': x2, 'y': y})).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.270
# Model:                            OLS   Adj. R-squared:                  0.255
# Method:                 Least Squares   F-statistic:                     18.13
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           2.00e-07
# Time:                        16:12:19   Log-Likelihood:                -148.99
# No. Observations:                 101   AIC:                             304.0
# Df Residuals:                      98   BIC:                             311.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.2148      0.222      9.978      0.000         1.774     2.655
# x              0.9179      0.578      1.589      0.115        -0.228     2.064
# z              2.1520      0.824      2.612      0.010         0.517     3.787
# ==============================================================================
# Omnibus:                        1.312   Durbin-Watson:                   2.306
# Prob(Omnibus):                  0.519   Jarque-Bera (JB):                1.298
# Skew:                          -0.171   Prob(JB):                        0.523
# Kurtosis:                       2.563   Cond. No.                         10.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='y~x', data=pd.DataFrame({'x': x1, 'z': x2, 'y': y})).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     27.80
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           7.90e-07
# Time:                        16:12:19   Log-Likelihood:                -152.39
# No. Observations:                 101   AIC:                             308.8
# Df Residuals:                      99   BIC:                             314.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.1632      0.227      9.509      0.000         1.712     2.615
# x              2.0564      0.390      5.273      0.000         1.283     2.830
# ==============================================================================
# Omnibus:                        1.170   Durbin-Watson:                   2.357
# Prob(Omnibus):                  0.557   Jarque-Bera (JB):                0.709
# Skew:                           0.166   Prob(JB):                        0.701
# Kurtosis:                       3.240   Cond. No.                         4.53
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='y~z', data=pd.DataFrame({'x': x1, 'z': x2, 'y': y})).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     33.22
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           9.34e-08
# Time:                        16:12:19   Log-Likelihood:                -150.27
# No. Observations:                 101   AIC:                             304.5
# Df Residuals:                      99   BIC:                             309.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2
0.42858864860156987, 0.3608373860393237, 0.21217128046202025, 0.05407851619295788, -0.3168253620389927, -0.051207130089424846, 0.5429671086141743, 0.01668769577938066, 0.08466449247222957, 0.3165509505521629, 0.15169944181229206, 0.30259228173397956, 0.13436007589278115, 0.25456022098242137, -0.08168986979428933, 0.46671301348184036, 0.24518375842239412, -0.05302374221175005, 0.4457453305070542, 0.03695596148672739, 0.3650869356335789, 0.3155872701073389, 0.241216665178585, 0.31564121373785237, 0.09981317881826283, 0.439275271345057, 0.3030989870326447, 0.09814608992966281, 0.06522875705177729, 0.21201858677741411, -0.06314869713069143, 0.4794790344728951, 0.21721144227215944, 0.2884082432453531, 0.09557770216795836, -0.034616937370336776, 0.46882065831289405, 0.4432684561071945, -0.08932218303515968, -0.036138782998418315, 0.25830566919928255, 0.36617142510515305, 0.3432883836596993, 0.1665710506345388, 0.14046666372595173, 0.4328423072370444, 0.014201307767970723, 0.26307246317608995, 0.4316636418469779, 0.13519039265752802, 0.11197763054546989, 0.36171538290192756, 0.5661829198112761, 0.23474013737721444, 0.19198754945240934, 0.24519428095779172, 0.07691618883882027, 0.2441857 ...

# %%
plt.scatter(x1,x2, alpha=0.5, c='#4a1f3d')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# Dado que ese último dato resulta ser un outlier de x2 (pero no un high-leverage point) crea más confusión en el modelo cuando sólo usamos x2 pero a x1 no lo afecta tanto porque es "normal" dentro de este universo.

# %% [markdown]
# ## EJERCICIO 11(CAPÍTULO 3 EJERCICIO 15)

# %% [markdown]
# ### (a)

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
for col in boston:
    boston[col]=preprocessing.scale(boston[col])

# %%
#Generemos las muestras de entrenamiento y de prueba
X_train, X_test, y_train, y_test = train_test_split(boston_sin_target, boston['target'], test_size=0.2)

# %%
for col in boston_sin_target:
    lm.fit(X_train[col].reshape(-1,1), y_train)
    plt.scatter(X_test[col].reshape(-1,1), y_test,alpha=0.5)
    plt.xlabel(str(col))
    plt.ylabel('y')
    plt.plot(X_test[col].reshape(-1,1), lm.predict(X_test[col].reshape(-1,1)), label='Regresión lineal por mínimos cuadrados', c='#cc99cc', alpha=0.9)
    plt.title('Scatter '+col+'vs y')
    plt.show()
    print('Score '+str(col)+': ',lm.score(X_test[col].reshape(-1,1), y_test))
# Out:
# Score CRIM:  0.158103990434
# Score ZN:  0.0304184510676
# Score INDUS:  0.145740865086
# Score CHAS:  0.101881049699
# Score NOX:  0.120258438249
# Score RM:  0.542563844638
# Score AGE:  0.0794928506197
# Score DIS:  0.00702872848261
# Score RAD:  0.120436721069
# Score TAX:  0.18349835612
# Score PTRATIO:  0.175323613632
# Score B:  0.123820522788
# Score LSTAT:  0.451066878688

# %%
boston.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.199458  0.404471 -0.055295  0.417521 -0.219940  0.350784
# ZN      -0.199458  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.404471 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055295 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.417521 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219940  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.350784 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.377904  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.622029 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.579564 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.288250 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.377365  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.452220 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# target  -0.385832  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT    target
# CRIM    -0.377904  0.622029  0.579564  0.288250 -0.377365  0.452220 -0.385832
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# target   0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %% [markdown]
# Los predictores que mejor modelan de forma lineal "target" son RM y LSTAT como se puede ver en las gráficas anteriores.

# %% [markdown]
# ### (b)

# %%
lm2=smf.ols(formula='target~CRIM+ZN+INDUS+CHAS+NOX+RM+AGE+DIS+RAD+TAX+PTRATIO+B+LSTAT', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):          6.95e-135
# Time:                        16:12:22   Log-Likelihood:                -376.58
# No. Observations:                 506   AIC:                             781.2
# Df Residuals:                     492   BIC:                             840.3
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.023  -2.46e-14      1.000        -0.045     0.045
# CRIM          -0.1002      0.031     -3.276      0.001        -0.160    -0.040
# ZN             0.1177      0.035      3.380      0.001         0.049     0.186
# INDUS          0.0156      0.046      0.339      0.735        -0.075     0.106
# CHAS           0.0742      0.024      3.120      0.002         0.027     0.121
# NOX           -0.2242      0.048     -4.658      0.000        -0.319    -0.130
# RM             0.2907      0.032      9.102      0.000         0.228     0.353
# AGE            0.0023      0.040      0.057      0.955        -0.077     0.082
# DIS           -0.3379      0.046     -7.398      0.000        -0.428    -0.248
# RAD            0.2894      0.063      4.608      0.000         0.166     0.413
# TAX           -0.2259      0.069     -3.278      0.001        -0.361    -0.091
# PTRATIO       -0.2244      0.031     -7.287      0.000        -0.285    -0.164
# B              0.0932      0.027      3.500      0.001         0.041     0.146
# LSTAT         -0.4080      0.039    -10.366      0.000        -0.485    -0.331
# ==============================================================================
# Omnibus:                      178.029   Durbin-Watson:                   1.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              782.015
# Skew:                           1.521   Prob(JB):                    1.54e-170
# Kurtosis:                       8.276   Cond. No.                         9.82
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Es curioso ver que la regresión indica que la edad no influye casi que nada en el target. Aparentemente INDUS tampoco. Únicamente para esas dos variables se rechaza la hipótesis nula.

# %% [markdown]
# ### (c)

# %% [markdown]
# Al hacer la regresión con todos los features se ve menos relación entre las variables predictoras con el target. Esto a pesar de que es intuitivo muestra que a veces es necesario analizar cada relación por separado o por grupo después de hacer reducción de variables o clusterings enre los datos.

# %%
params=[]
for col in boston_sin_target:
    lm.fit(X_train[col].reshape(-1,1), y_train)
    params.append(lm.coef_[0])

# %%
plt.scatter(preprocessing.scale(np.array(params)), preprocessing.scale(lm2.params[1:].values), alpha=0.5)
plt.xlim(-0.5,1)
plt.ylim(-2,2)
plt.xlabel('simple')
plt.ylabel('múltiple')
plt.title('Comparacion de los dos modelos')
plt.show()

# %% [markdown]
# Solamente hay dos puntos que están cerca a y=x. Son muy diferentes los modelos.

# %% [markdown]
# ### (d)

# %%
lm2=smf.ols(formula='target~CRIM+I(CRIM**2)+I(CRIM**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.214
# Model:                            OLS   Adj. R-squared:                  0.210
# Method:                 Least Squares   F-statistic:                     45.64
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           4.26e-26
# Time:                        16:12:22   Log-Likelihood:                -656.96
# No. Observations:                 506   AIC:                             1322.
# Df Residuals:                     502   BIC:                             1339.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept       -0.1231      0.048     -2.584      0.010        -0.217    -0.030
# CRIM            -0.9012      0.098     -9.154      0.000        -1.095    -0.708
# I(CRIM ** 2)     0.1759      0.049      3.571      0.000         0.079     0.273
# I(CRIM ** 3)    -0.0101      0.005     -2.200      0.028        -0.019    -0.001
# ==============================================================================
# Omnibus:                      166.156   Durbin-Watson:                   0.682
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              436.497
# Skew:                           1.642   Prob(JB):                     1.64e-95
# Kurtosis:                       6.149   Cond. No.                         152.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~CRIM', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.149
# Model:                            OLS   Adj. R-squared:                  0.147
# Method:                 Least Squares   F-statistic:                     88.15
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           2.08e-19
# Time:                        16:12:22   Log-Likelihood:                -677.20
# No. Observations:                 506   AIC:                             1358.
# Df Residuals:                     504   BIC:                             1367.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.041  -1.37e-14      1.000        -0.081     0.081
# CRIM          -0.3858      0.041     -9.389      0.000        -0.467    -0.305
# ==============================================================================
# Omnibus:                      138.965   Durbin-Watson:                   0.712
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              292.343
# Skew:                           1.483   Prob(JB):                     3.30e-64
# Kurtosis:                       5.251   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Para CRIM hay una leve mejora pero dado el aumento en complejidad no es significativo.

# %%
lm2=smf.ols(formula='target~ZN+I(ZN**2)+I(ZN**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.160
# Method:                 Least Squares   F-statistic:                     33.05
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           1.66e-19
# Time:                        16:12:22   Log-Likelihood:                -672.38
# No. Observations:                 506   AIC:                             1353.
# Df Residuals:                     502   BIC:                             1370.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.3533      0.087      4.053      0.000         0.182     0.525
# ZN             0.7888      0.113      7.004      0.000         0.568     1.010
# I(ZN ** 2)    -0.7373      0.167     -4.406      0.000        -1.066    -0.409
# I(ZN ** 3)     0.1730      0.044      3.978      0.000         0.088     0.259
# ==============================================================================
# Omnibus:                      131.269   Durbin-Watson:                   0.609
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              295.924
# Skew:                           1.352   Prob(JB):                     5.51e-65
# Kurtosis:                       5.593   Cond. No.                         44.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~ZN', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     75.26
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           5.71e-17
# Time:                        16:12:22   Log-Likelihood:                -682.77
# No. Observations:                 506   AIC:                             1370.
# Df Residuals:                     504   BIC:                             1378.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.042  -1.36e-14      1.000        -0.082     0.082
# ZN             0.3604      0.042      8.675      0.000         0.279     0.442
# ==============================================================================
# Omnibus:                      123.531   Durbin-Watson:                   0.618
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              262.387
# Skew:                           1.303   Prob(JB):                     1.06e-57
# Kurtosis:                       5.378   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Despreciable...

# %%
lm2=smf.ols(formula='target~INDUS+I(INDUS**2)+I(INDUS**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     64.06
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           4.42e-35
# Time:                        16:12:22   Log-Likelihood:                -635.98
# No. Observations:                 506   AIC:                             1280.
# Df Residuals:                     502   BIC:                             1297.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        -0.2836      0.064     -4.403      0.000        -0.410    -0.157
# INDUS            -0.4259      0.066     -6.446      0.000        -0.556    -0.296
# I(INDUS ** 2)     0.3083      0.058      5.349      0.000         0.195     0.422
# I(INDUS ** 3)    -0.0841      0.035     -2.373      0.018        -0.154    -0.014
# ==============================================================================
# Omnibus:                      178.737   Durbin-Watson:                   0.703
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              603.414
# Skew:                           1.642   Prob(JB):                    9.34e-132
# Kurtosis:                       7.224   Cond. No.                         5.88
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~INDUS', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     154.0
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           4.90e-31
# Time:                        16:12:22   Log-Likelihood:                -650.54
# No. Observations:                 506   AIC:                             1305.
# Df Residuals:                     504   BIC:                             1314.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.039  -1.45e-14      1.000        -0.077     0.077
# INDUS         -0.4837      0.039    -12.408      0.000        -0.560    -0.407
# ==============================================================================
# Omnibus:                      178.432   Durbin-Watson:                   0.676
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              562.993
# Skew:                           1.672   Prob(JB):                    5.59e-123
# Kurtosis:                       6.939   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~NOX+I(NOX**2)+I(NOX**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     40.24
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           2.56e-23
# Time:                        16:12:22   Log-Likelihood:                -663.46
# No. Observations:                 506   AIC:                             1335.
# Df Residuals:                     502   BIC:                             1352.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       0.0053      0.061      0.087      0.931        -0.114     0.124
# NOX            -0.5651      0.067     -8.492      0.000        -0.696    -0.434
# I(NOX ** 2)    -0.0483      0.062     -0.784      0.433        -0.169     0.073
# I(NOX ** 3)     0.0591      0.029      2.049      0.041         0.002     0.116
# ==============================================================================
# Omnibus:                      184.605   Durbin-Watson:                   0.656
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              543.951
# Skew:                           1.777   Prob(JB):                    7.63e-119
# Kurtosis:                       6.628   Cond. No.                         9.43
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~NOX', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.183
# Model:                            OLS   Adj. R-squared:                  0.181
# Method:                 Least Squares   F-statistic:                     112.6
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           7.07e-24
# Time:                        16:12:22   Log-Likelihood:                -666.97
# No. Observations:                 506   AIC:                             1338.
# Df Residuals:                     504   BIC:                             1346.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.040   -1.4e-14      1.000        -0.079     0.079
# NOX           -0.4273      0.040    -10.611      0.000        -0.506    -0.348
# ==============================================================================
# Omnibus:                      165.520   Durbin-Watson:                   0.643
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              430.900
# Skew:                           1.641   Prob(JB):                     2.70e-94
# Kurtosis:                       6.109   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~RM+I(RM**2)+I(RM**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.561
# Model:                            OLS   Adj. R-squared:                  0.559
# Method:                 Least Squares   F-statistic:                     214.0
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           2.14e-89
# Time:                        16:12:22   Log-Likelihood:                -509.57
# No. Observations:                 506   AIC:                             1027.
# Df Residuals:                     502   BIC:                             1044.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.1245      0.033     -3.730      0.000        -0.190    -0.059
# RM             0.7762      0.046     16.775      0.000         0.685     0.867
# I(RM ** 2)     0.1358      0.015      8.818      0.000         0.106     0.166
# I(RM ** 3)    -0.0279      0.007     -3.827      0.000        -0.042    -0.014
# ==============================================================================
# Omnibus:                       83.263   Durbin-Watson:                   0.662
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              809.956
# Skew:                           0.336   Prob(JB):                    1.32e-176
# Kurtosis:                       9.162   Cond. No.                         10.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~RM', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     471.8
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           2.49e-74
# Time:                        16:12:22   Log-Likelihood:                -550.82
# No. Observations:                 506   AIC:                             1106.
# Df Residuals:                     504   BIC:                             1114.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.032  -1.76e-14      1.000        -0.063     0.063
# RM             0.6954      0.032     21.722      0.000         0.632     0.758
# ==============================================================================
# Omnibus:                      102.585   Durbin-Watson:                   0.684
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              612.449
# Skew:                           0.726   Prob(JB):                    1.02e-133
# Kurtosis:                       8.190   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~AGE+I(AGE**2)+I(AGE**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     31.06
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           1.96e-18
# Time:                        16:12:22   Log-Likelihood:                -674.90
# No. Observations:                 506   AIC:                             1358.
# Df Residuals:                     502   BIC:                             1375.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       0.1743      0.074      2.354      0.019         0.029     0.320
# AGE            -0.3871      0.087     -4.448      0.000        -0.558    -0.216
# I(AGE ** 2)    -0.2078      0.085     -2.438      0.015        -0.375    -0.040
# I(AGE ** 3)    -0.0561      0.055     -1.017      0.310        -0.164     0.052
# ==============================================================================
# Omnibus:                      181.718   Durbin-Watson:                   0.631
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              531.101
# Skew:                           1.750   Prob(JB):                    4.71e-116
# Kurtosis:                       6.597   Cond. No.                         8.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~AGE', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.140
# Method:                 Least Squares   F-statistic:                     83.48
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           1.57e-18
# Time:                        16:12:22   Log-Likelihood:                -679.21
# No. Observations:                 506   AIC:                             1362.
# Df Residuals:                     504   BIC:                             1371.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.041  -1.37e-14      1.000        -0.081     0.081
# AGE           -0.3770      0.041     -9.137      0.000        -0.458    -0.296
# ==============================================================================
# Omnibus:                      170.034   Durbin-Watson:                   0.613
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              456.983
# Skew:                           1.671   Prob(JB):                    5.85e-100
# Kurtosis:                       6.240   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~DIS+I(DIS**2)+I(DIS**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.105
# Model:                            OLS   Adj. R-squared:                  0.100
# Method:                 Least Squares   F-statistic:                     19.64
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           4.74e-12
# Time:                        16:12:22   Log-Likelihood:                -689.91
# No. Observations:                 506   AIC:                             1388.
# Df Residuals:                     502   BIC:                             1405.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       0.2374      0.066      3.572      0.000         0.107     0.368
# DIS             0.3501      0.059      5.886      0.000         0.233     0.467
# I(DIS ** 2)    -0.2946      0.071     -4.121      0.000        -0.435    -0.154
# I(DIS ** 3)     0.0568      0.025      2.307      0.021         0.008     0.105
# ==============================================================================
# Omnibus:                      178.748   Durbin-Watson:                   0.593
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              508.094
# Skew:                           1.734   Prob(JB):                    4.66e-111
# Kurtosis:                       6.474   Cond. No.                         11.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~DIS', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           1.21e-08
# Time:                        16:12:22   Log-Likelihood:                -701.66
# No. Observations:                 506   AIC:                             1407.
# Df Residuals:                     504   BIC:                             1416.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.043  -1.31e-14      1.000        -0.085     0.085
# DIS            0.2499      0.043      5.795      0.000         0.165     0.335
# ==============================================================================
# Omnibus:                      139.779   Durbin-Watson:                   0.570
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              305.104
# Skew:                           1.466   Prob(JB):                     5.59e-67
# Kurtosis:                       5.424   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~RAD+I(RAD**2)+I(RAD**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.172
# Method:                 Least Squares   F-statistic:                     35.91
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           4.87e-21
# Time:                        16:12:22   Log-Likelihood:                -668.79
# No. Observations:                 506   AIC:                             1346.
# Df Residuals:                     502   BIC:                             1362.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.1047      0.261      4.235      0.000         0.592     1.617
# RAD             2.3450      0.703      3.336      0.001         0.964     3.726
# I(RAD ** 2)     0.3369      0.213      1.585      0.114        -0.081     0.754
# I(RAD ** 3)    -1.4389      0.410     -3.514      0.000        -2.244    -0.634
# ==============================================================================
# Omnibus:                      157.768   Durbin-Watson:                   0.663
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              402.908
# Skew:                           1.567   Prob(JB):                     3.23e-88
# Kurtosis:                       6.048   Cond. No.                         62.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~RAD', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.144
# Method:                 Least Squares   F-statistic:                     85.91
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           5.47e-19
# Time:                        16:12:22   Log-Likelihood:                -678.16
# No. Observations:                 506   AIC:                             1360.
# Df Residuals:                     504   BIC:                             1369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.041  -1.37e-14      1.000        -0.081     0.081
# RAD           -0.3816      0.041     -9.269      0.000        -0.463    -0.301
# ==============================================================================
# Omnibus:                      149.634   Durbin-Watson:                   0.632
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              359.231
# Skew:                           1.515   Prob(JB):                     9.86e-79
# Kurtosis:                       5.803   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~TAX+I(TAX**2)+I(TAX**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.226
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     48.89
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           9.82e-28
# Time:                        16:12:22   Log-Likelihood:                -653.13
# No. Observations:                 506   AIC:                             1314.
# Df Residuals:                     502   BIC:                             1331.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept      -0.0771      0.082     -0.935      0.350        -0.239     0.085
# TAX            -0.3677      0.198     -1.857      0.064        -0.757     0.021
# I(TAX ** 2)     0.1492      0.073      2.056      0.040         0.007     0.292
# I(TAX ** 3)    -0.1080      0.116     -0.930      0.353        -0.336     0.120
# ==============================================================================
# Omnibus:                      170.144   Durbin-Watson:                   0.644
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              490.879
# Skew:                           1.632   Prob(JB):                    2.55e-107
# Kurtosis:                       6.555   Cond. No.                         14.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~TAX', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.220
# Model:                            OLS   Adj. R-squared:                  0.218
# Method:                 Least Squares   F-statistic:                     141.8
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           5.64e-29
# Time:                        16:12:22   Log-Likelihood:                -655.28
# No. Observations:                 506   AIC:                             1315.
# Df Residuals:                     504   BIC:                             1323.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.039  -1.43e-14      1.000        -0.077     0.077
# TAX           -0.4685      0.039    -11.906      0.000        -0.546    -0.391
# ==============================================================================
# Omnibus:                      172.501   Durbin-Watson:                   0.648
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              494.072
# Skew:                           1.661   Prob(JB):                    5.17e-108
# Kurtosis:                       6.521   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Impresionante la mejora...

# %%
lm2=smf.ols(formula='target~PTRATIO+I(PTRATIO**2)+I(PTRATIO**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.262
# Method:                 Least Squares   F-statistic:                     60.91
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           1.35e-33
# Time:                        16:12:22   Log-Likelihood:                -639.45
# No. Observations:                 506   AIC:                             1287.
# Df Residuals:                     502   BIC:                             1304.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           0.1070      0.059      1.818      0.070        -0.009     0.223
# PTRATIO            -0.4640      0.068     -6.790      0.000        -0.598    -0.330
# I(PTRATIO ** 2)    -0.1570      0.063     -2.475      0.014        -0.282    -0.032
# I(PTRATIO ** 3)    -0.0626      0.033     -1.892      0.059        -0.128     0.002
# ==============================================================================
# Omnibus:                       98.389   Durbin-Watson:                   0.735
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              200.314
# Skew:                           1.062   Prob(JB):                     3.18e-44
# Kurtosis:                       5.235   Cond. No.                         8.82
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~PTRATIO', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.258
# Model:                            OLS   Adj. R-squared:                  0.256
# Method:                 Least Squares   F-statistic:                     175.1
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           1.61e-34
# Time:                        16:12:22   Log-Likelihood:                -642.54
# No. Observations:                 506   AIC:                             1289.
# Df Residuals:                     504   BIC:                             1298.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.038  -1.47e-14      1.000        -0.075     0.075
# PTRATIO       -0.5078      0.038    -13.233      0.000        -0.583    -0.432
# ==============================================================================
# Omnibus:                       92.924   Durbin-Watson:                   0.725
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              191.444
# Skew:                           1.001   Prob(JB):                     2.68e-42
# Kurtosis:                       5.252   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~B+I(B**2)+I(B**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.114
# Model:                            OLS   Adj. R-squared:                  0.108
# Method:                 Least Squares   F-statistic:                     21.43
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           4.46e-13
# Time:                        16:12:23   Log-Likelihood:                -687.49
# No. Observations:                 506   AIC:                             1383.
# Df Residuals:                     502   BIC:                             1400.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.0218      0.084     -0.259      0.796        -0.187     0.144
# B              0.4300      0.166      2.588      0.010         0.104     0.756
# I(B ** 2)     -0.0311      0.176     -0.177      0.860        -0.377     0.315
# I(B ** 3)     -0.0184      0.039     -0.467      0.641        -0.096     0.059
# ==============================================================================
# Omnibus:                      104.127   Durbin-Watson:                   0.588
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              190.733
# Skew:                           1.178   Prob(JB):                     3.83e-42
# Kurtosis:                       4.870   Cond. No.                         67.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~B', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.109
# Method:                 Least Squares   F-statistic:                     63.05
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           1.32e-14
# Time:                        16:12:23   Log-Likelihood:                -688.16
# No. Observations:                 506   AIC:                             1380.
# Df Residuals:                     504   BIC:                             1389.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.042  -1.34e-14      1.000        -0.083     0.083
# B              0.3335      0.042      7.941      0.000         0.251     0.416
# ==============================================================================
# Omnibus:                      103.788   Durbin-Watson:                   0.588
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              189.336
# Skew:                           1.177   Prob(JB):                     7.70e-42
# Kurtosis:                       4.855   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~LSTAT+I(LSTAT**2)+I(LSTAT**3)', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.658
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                     321.7
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):          1.78e-116
# Time:                        16:12:23   Log-Likelihood:                -446.64
# No. Observations:                 506   AIC:                             901.3
# Df Residuals:                     502   BIC:                             918.2
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        -0.3310      0.038     -8.806      0.000        -0.405    -0.257
# LSTAT            -0.8262      0.041    -20.133      0.000        -0.907    -0.746
# I(LSTAT ** 2)     0.4025      0.038     10.585      0.000         0.328     0.477
# I(LSTAT ** 3)    -0.0792      0.016     -5.013      0.000        -0.110    -0.048
# ==============================================================================
# Omnibus:                      107.925   Durbin-Watson:                   0.906
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              258.171
# Skew:                           1.088   Prob(JB):                     8.69e-57
# Kurtosis:                       5.741   Cond. No.                         10.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2=smf.ols(formula='target~LSTAT', data=boston).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     601.6
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):           5.08e-88
# Time:                        16:12:23   Log-Likelihood:                -519.23
# No. Observations:                 506   AIC:                             1042.
# Df Residuals:                     504   BIC:                             1051.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -5.638e-16      0.030  -1.87e-14      1.000        -0.059     0.059
# LSTAT         -0.7377      0.030    -24.528      0.000        -0.797    -0.679
# ==============================================================================
# Omnibus:                      137.043   Durbin-Watson:                   0.892
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              291.373
# Skew:                           1.453   Prob(JB):                     5.36e-64
# Kurtosis:                       5.319   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## CONCLUSIÓN 1

# %% [markdown]
# Entre mejor sea el feature para predecir el target mayor es la mejora de la aproximación polinómica. Sin embargo en ninguno de los casos el aumento en complejidad resulta en una mejora significativa del modelo.

# %% [markdown]
# ## EJERCICIO 12 (CAPÍTULO 4 EJERCICIO 10)

# %% [markdown]
# ### (a)

# %%
weekly=pd.read_csv('data/Weekly.csv')
weekly.shape
# Out:
# (1089, 9)

# %%
weekly.head()
# Out:
#    Year   Lag1   Lag2   Lag3   Lag4   Lag5    Volume  Today Direction
# 0  1990  0.816  1.572 -3.936 -0.229 -3.484  0.154976 -0.270      Down
# 1  1990 -0.270  0.816  1.572 -3.936 -0.229  0.148574 -2.576      Down
# 2  1990 -2.576 -0.270  0.816  1.572 -3.936  0.159837  3.514        Up
# 3  1990  3.514 -2.576 -0.270  0.816  1.572  0.161630  0.712        Up
# 4  1990  0.712  3.514 -2.576 -0.270  0.816  0.153728  1.178        Up

# %%
weekly.describe()
# Out:
#               Year         Lag1         Lag2         Lag3         Lag4  \
# count  1089.000000  1089.000000  1089.000000  1089.000000  1089.000000
# mean   2000.048669     0.150585     0.151079     0.147205     0.145818
# std       6.033182     2.357013     2.357254     2.360502     2.360279
# min    1990.000000   -18.195000   -18.195000   -18.195000   -18.195000
# 25%    1995.000000    -1.154000    -1.154000    -1.158000    -1.158000
# 50%    2000.000000     0.241000     0.241000     0.241000     0.238000
# 75%    2005.000000     1.405000     1.409000     1.409000     1.409000
# max    2010.000000    12.026000    12.026000    12.026000    12.026000
#
#               Lag5       Volume        Today
# count  1089.000000  1089.000000  1089.000000
# mean      0.139893     1.574618     0.149899
# std       2.361285     1.686636     2.356927
# min     -18.195000     0.087465   -18.195000
# 25%      -1.166000     0.332022    -1.154000
# 50%       0.234000     1.002680     0.241000
# 75%       1.405000     2.053727     1.405000
# max      12.026000     9.328214    12.026000

# %% [markdown]
# Note que la mediana del lag permanece casi constante sin importar cuantas semanas se tengan en cuenta. Para ver su comportamiento, veamos unos box plots...

# %%
trace1 = go.Box(
    y=weekly['Lag1'],
    name = 'lag1',
    marker = dict(
        color = '#9932cc',
    )
)
trace2 = go.Box(
    y=weekly['Lag2'],
    name = 'lag2',
    marker = dict(
        color = '#ff00ff',
    )
)
trace3 = go.Box(
    y=weekly['Lag3'],
    name = 'lag3',
    marker = dict(
        color = '#00b300',
    )
)
trace4 = go.Box(
    y=weekly['Lag4'],
    name = 'lag4',
    marker = dict(
        color = '#ff00ff',
    )
)
trace5 = go.Box(
    y=weekly['Lag5'],
    name = 'lag5',
    marker = dict(
        color = '#1abb9c',
    )
)

layout = go.Layout(
    title = "Boxplots",
    
    yaxis=dict(
        title='mpg',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)
data = [trace1, trace2, trace3, trace4, trace5]
fig = go.Figure(data=data,layout=layout)
py.iplot(data)
# Out:
# <div id="35f78c02-4ab8-4b98-a304-22027e3dee90" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("35f78c02-4ab8-4b98-a304-22027e3dee90", [{"y": [0.816, -0.27, -2.576, 3.514, 0.7120000000000001, 1.178, -1.3719999999999999, 0.807, 0.040999999999999995, 1.253, -2.678, -1.7930000000000001, 2.82, 4.022, 0.75, -0.017, 2.42, -1.225, 1.171, -2.061, 0.7290000000000001, 0.11199999999999999, 2.48, -1.5519999999999998, -2.259, -2.428, -2.708, -2.292, -4.978, 3.5469999999999997, 0.26, -2.032, -1.739, -1.693, 1.781, -3.682, 4.15, -2.487, 2.343, 0.606, 1.077, -0.637, 2.26, 1.716, -0.284, 1.508, -0.9129999999999999, -2
630000000000002, -0.278, 0.461, -0.32899999999999996, 0.345, 0.506, -1.321, 1.875, 0.364, 1.24, -0.017, 1.168, 1.73, -0.185, -0.7120000000000001, 0.65, 0.127, -2.416, 1.665, 1.6, 2.2880000000000003, 3.2289999999999996, -1.278, 1.713, -2.2319999999999998, -1.6869999999999998, 1.252, 1.433, -0.787, 1.605, -2.92, 1.3130000000000002, 1.301, -1.81, 1.63, 2.5789999999999997, 1.435, -1.3840000000000001, 0.626, -1.1079999999999999, 0.149, 0.568, -1.9669999999999999, -1.7109999999999999, -1.1540000000000001, -0.44299999999999995, 4.181, -0.059000000000000004, 0.47, 0.27399999999999997, -2.255, 0.5660000000000001 ...

# %% [markdown]
# No hay diferencia entre los lags. Eso era de suponerse. Por ello definamos una nueva variable "Lag" como el promedio de ellos y trabajemos solo con el volum, un lag, today y el año.

# %%
weekly['lag']=(weekly['Lag1']+weekly['Lag2']+weekly['Lag3']+weekly['Lag4']+weekly['Lag5'])/5

# %%
weekly_tmp=weekly.drop(['Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5'], axis=1)

# %%
weekly_tmp.head()
# Out:
#    Year    Volume  Today Direction     lag
# 0  1990  0.154976 -0.270      Down -1.0522
# 1  1990  0.148574 -2.576      Down -0.4094
# 2  1990  0.159837  3.514        Up -0.8788
# 3  1990  0.161630  0.712        Up  0.6112
# 4  1990  0.153728  1.178        Up  0.4392

# %%
for col in weekly_tmp.drop(['Year', 'Direction'], axis=1):
    weekly_tmp[col]=preprocessing.scale(weekly_tmp[col])

# %%
scatter_matrix(weekly_tmp[['Volume', 'Today', 'lag']], c='#14396c', alpha=0.2, diagonal='kde')
plt.show()

# %% [markdown]
# ## Observación 1

# %% [markdown]
# A pesar que los scatters no dicen nada, las estimaciones de densidad de las variables continuas reflejan la intuición: el volumen tiene una distribución chi cuadrado tirada hacia la izquierda (y el volumen siempre es positivo, acotado y cola liviana), y las otras dos son normales centradas en 0 con colas pequeñas.

# %%
dir_down=weekly[weekly['Direction']=='Down']
dir_up=weekly[weekly['Direction']=='Up']

# %%
weekly['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010])

# %%
def label_encoder_year(x):
    if x<np.percentile(weekly['Year'], q=33):
        return 0
    elif (x>=np.percentile(weekly['Year'], q=33)) & (x<np.percentile(weekly['Year'], q=66)):
        return 1
    else:
        return 2

# %%
weekly['Year_cat']=[label_encoder_year(x) for x in weekly['Year']]

# %%
#volume respecto a direction
trace1 = go.Box(
    y=preprocessing.scale(dir_down['Volume']),
    name = 'Down',
    marker = dict(
        color = '#9932cc',
    )
)
trace2 = go.Box(
    y=preprocessing.scale(dir_up['Volume']),
    name = 'Up',
    marker = dict(
        color = '#ff00ff',
    )
)


layout = go.Layout(
    title = "Boxplots",
    
    yaxis=dict(
        title='mpg',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)
data = [trace1, trace2]
fig = go.Figure(data=data,layout=layout)
py.iplot(data)
# Out:
# <div id="975f895b-fb23-400b-8ca3-78f4e32a1b2b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("975f895b-fb23-400b-8ca3-78f4e32a1b2b", [{"y": [-0.8564029656257117, -0.8601748719393868, -0.8567164073874853, -0.8689765758475392, -0.8599097426296157, -0.8442235143110771, -0.8460045940964941, -0.8562167859326281, -0.8466061430415522, -0.8493446342233644, -0.8465389769497437, -0.8240925404082892, -0.8341733459420254, -0.860364586689934, -0.879518411792155, -0.8746980663523968, -0.8598755704074675,
230762742055827, -1.2840391287981845, 0.3568189462978073, 0.9154365058289071, 0.5233673370164763, -0.7079242675184306, 0.9102521201256022, -0.16291572045850608, -0.4111181860042268, 1.2906564211055973, 0.054180430867385415, -1.190720186138697, -1.0708312667497717, 0.5784514351140905, -0.4908281161925392, -0.9340930938251057, -0.11949649019332778, 1.7242006755444668, -1.523816967576035, 1.0476383412631813, 0.10667233611334724, -1.847193025819676, -1.250988669939616, -0.3119668094285211, 0.5168868548873452, 0.7650893204330657, 0.27970120896114725, 3.098710935133171, 1.9004697894568323, -0.8083717405199624, 0.4339366836344672, -0.6761699050856883, -1.1984967646936542, 0.21295224303109705, 0.06584529869982135, -0.3184472915576522, 0.04705190052534121, -1.4499394713039404, 0.07102968440312626, 0.7184298491033221, -1.3818944089480638, -0.466202284101841, 0.2887738839419309, 1.7300331094606851, -1.246452332449224, 0.40283036941463796, 0.39959012835007246, -1.0818480863692945, 0.46763519070594883, 0.054828479080298524, -0.4448166930757085, -0.7364383888866074, -1.1161946416536892, -0.1881896007621173, 1.1830804177620209, 0.295254366071062, 0.0029846220472498192, -0.7798576191517859, 1.832424727100956, -0.9671435526836741, 0.006224863111815367, -0.9340930938251057, -0.15449109369063566, 0.19675103770826938, 0.23498588227014278, 0.36394747663985144, -1.4680848212655073, -0.7597681245514794, -1.3864307464384558, 1.3068576264284248, 0.22008077337314133, 0.5635463262170889, -0.3236316772609571, 0.59918897792731, 0.4942051674353864, 0.38014868196267915, 0.1332423128427847, 0.09759966113256371, 0.9750569414169131, -0.3748274860810927, -0.7513434977836089, -1.144060714808953, 1.0703200287151402, -0.30743047193812933, 0.2434105090380132, 1.3457405192032115, -0.7811537155776119, -1.6631473333523532, 1.2141867319818502, 0.24600270188966564, 0.38727721230472345, -0.10264723665758693, -0.4986046947474964, -1.0779597970918156, -0.08709407954767234, 0.8882184808865566, -1.8724669061232875, 0.31534386067136827, 0.15916424135930907, -0.5562809856967632, 0.7728658989880233, 0.4793000585383848, -0.17198839543928962, -0.5562809856967632, -0.6716335675952965, 0.4196796229503788, -0.4078779449396612, 0.176661543107963, -0.49 ...

# %% [markdown]
# ## Conclusión 1

# %% [markdown]
# La volatilidad del mercado de los últimos años es mayor que en el pasado.

# %%
#today respecto a year
trace1 = go.Box(
    y=preprocessing.scale(year_0['Volume']),
    name = 'Categoria 0 Year',
    marker = dict(
        color = '#9932cc',
    )
)
trace2 = go.Box(
    y=preprocessing.scale(year_1['Volume']),
    name = 'Categoría 1 Year',
    marker = dict(
        color = '#ff00ff',
    )
)

trace3 = go.Box(
    y=preprocessing.scale(year_2['Volume']),
    name = 'Categoría 3 Year',
    marker = dict(
        color = '#00bec9',
    )
)

layout = go.Layout(
    title = "Boxplots",
    
    yaxis=dict(
        title='mpg',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)
data = [trace1, trace2, trace3]
fig = go.Figure(data=data,layout=layout)
py.iplot(data)
# Out:
# <div id="7f8eaf8c-e9c6-45a2-a308-eb5cab2e441a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7
.12793458133912858, 0.45139015523794784, -0.25477215273024284, 0.5387301851521905, 0.2604209657886588, -0.1283887036372941, 0.018169556940180707, -0.1951916974864941, -0.23571694449458533, -0.12636902718835324, 0.31148914339026873, 0.09353422269249867, 0.20729469397956798, 0.014986371232611085, -0.17391923575797777, -0.15192232486842888, 0.16861349938137848, -0.2696562900387398, -0.06409932884683037, -0.24111738369501348, -0.1 ...

# %% [markdown]
# ## Conclusión 2

# %% [markdown]
# A pesar de que la volatilidad del mercado ha aumentado, esta gráfica muestra que el volumen de acciones intercambiadas en promedio ha ido disminuyendo (a pesar de que también se puede concluir que los que casi no jugaban en la bolsa antes han empezado a entrar al mercado), entonces sería interesante entender de donde ha venido este aumento en la incertidumbre del mercado.

# %% [markdown]
# ### (b)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
def bool_direction(x):
    if x=='Down':
        return 0
    else:
        return 1

# %%
weekly['Direction_bool']=[bool_direction(x) for x in weekly['Direction']]

# %%
model.fit(weekly[['Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume']], weekly['Direction_bool'])
model.coef_
# Out:
# array([[-0.04117292,  0.05846974, -0.01599122, -0.02769998, -0.01440289,
#         -0.02212844]])

# %%
model.score(weekly[['Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume']], weekly['Direction_bool'])
# Out:
# 0.56290174471992649

# %% [markdown]
# Veamos a ver si con un solo lag el modelo mejora...

# %%
model.fit(weekly[['lag', 'Volume']], weekly['Direction_bool'])
model.coef_
# Out:
# array([[-0.04392492, -0.0249872 ]])

# %%
model.score(weekly[['lag', 'Volume']], weekly['Direction_bool'])
# Out:
# 0.55555555555555558

# %% [markdown]
# Por esa pequeña diferencia preferimos de ahora en adelante solo trabajar con lag y no con todas las 5 variables que complejizan el estudio.

# %% [markdown]
# Sin embargo ninguna de las variables parecen significantes en la calisificación. Por eso es que el modelo es prácticamente tirar una moneda al aire.

# %% [markdown]
# ### (c)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(weekly['Direction_bool'], model.predict(weekly[['lag', 'Volume']]))
# Out:
# array([[  3, 481],
#        [  3, 602]])

# %% [markdown]
# ## Observación 1

# %% [markdown]
# El modelo tiende a marcar con 0's las direcciones.

# %% [markdown]
# ### (d)

# %%
model.fit(weekly['Lag2'].reshape(-1,1), weekly['Direction_bool'])
model.coef_
# Out:
# array([[ 0.06276314]])

# %%
model.score(weekly['Lag2'].reshape(-1,1), weekly['Direction_bool'])
# Out:
# 0.56106519742883376

# %%
confusion_matrix(weekly['Direction_bool'], model.predict(weekly['Lag2'].reshape(-1,1)))
# Out:
# array([[ 33, 451],
#        [ 27, 578]])

# %% [markdown]
# El modelo mejora un poco que al usar el promedio de los Lags. Dos semanas parece ser el intervalo de tiempo menos insuficiente para predecir la dirección del mercado.

# %% [markdown]
# ### (e)

# %%
from sklearn import cross_validation
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from matplotlib import colors

# %%
lda = LinearDiscriminantAnalysis(n_components=2)
lda.fit(weekly['Lag2'].reshape(-1,1), weekly['Direction_bool'])
drA = lda.transform(weekly['Lag2'].reshape(-1,1))

# %%
lda = LinearDiscriminantAnalysis()
k_fold = cross_validation.KFold(len(weekly['Lag2'].reshape(-1,1)), 3, shuffle=True)
print('LDA Results: ')
for (trn, tst) in k_fold:
    lda.fit(weekly['Lag2'].reshape(-1,1)[trn], weekly['Direction_bool'][trn])
    outVal = lda.score(weekly['Lag2'].reshape(-1,1)[tst], weekly['Direction_bool'][tst])
    #Compute classification error
print('Score: ' + str(outVal))
# Out:
# LDA Results:
# Score: 0.584022038567

# %% [markdown]
# ### (f)

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
qda=QuadraticDiscriminantAnalysis()

# %%
k_fold = cross_validation.KFold(len(weekly['Lag2'].reshape(-1,1)), 3, shuffle=True)
print('QDA Results: ')
for (trn, tst) in k_fold:
    qda.fit(weekly['Lag2'].reshape(-1,1)[trn], weekly['Direction_bool'][trn])
    outVal = qda.score(weekly['Lag2'].reshape(-1,1)[tst], weekly['Direction_bool'][tst])
    #Compute classification error
print('Score: ' + str(outVal))
# Out:
# QDA Results:
# Score: 0.528925619835

# %% [markdown]
# ### (g)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh=KNeighborsClassifier(n_neighbors=1)

# %%
k_fold = cross_validation.KFold(len(weekly['Lag2'].reshape(-1,1)), 3, shuffle=True)
print('KNN Results: ')
for (trn, tst) in k_fold:
    neigh.fit(weekly['Lag2'].reshape(-1,1)[trn], weekly['Direction_bool'][trn])
    outVal = neigh.score(weekly['Lag2'].reshape(-1,1)[tst], weekly['Direction_bool'][tst])
    #Compute classification error
print('Score: ' + str(outVal))
# Out:
# KNN Results:
# Score: 0.471074380165

# %% [markdown]
# ### (h)

# %% [markdown]
# El mejor es LDA.

# %%
#Hacemos el modelo KNN con k=2
from sklearn.neighbors import KNeighborsClassifier
neigh_2=KNeighborsClassifier(n_neighbors=2)

# %%
k_fold = cross_validation.KFold(len(weekly['Lag2'].reshape(-1,1)), 3, shuffle=True)
print('KNN Results: ')
for (trn, tst) in k_fold:
    neigh_2.fit(weekly['Lag2'].reshape(-1,1)[trn], weekly['Direction_bool'][trn])
    outVal = neigh_2.score(weekly['Lag2'].reshape(-1,1)[tst], weekly['Direction_bool'][tst])
    #Compute classification error
print('Score: ' + str(outVal))
# Out:
# KNN Results:
# Score: 0.446280991736

# %%
#Hacemos el modelo KNN con k=3
from sklearn.neighbors import KNeighborsClassifier
neigh_3=KNeighborsClassifier(n_neighbors=2)
k_fold = cross_validation.KFold(len(weekly['Lag2'].reshape(-1,1)), 3, shuffle=True)
print('KNN Results: ')
for (trn, tst) in k_fold:
    neigh_3.fit(weekly['Lag2'].reshape(-1,1)[trn], weekly['Direction_bool'][trn])
    outVal = neigh_3.score(weekly['Lag2'].reshape(-1,1)[tst], weekly['Direction_bool'][tst])
    #Compute classification error
print('Score: ' + str(outVal))
# Out:
# KNN Results:
# Score: 0.451790633609

# %%
#Hacemos una regresión cuadrática con Lag2
lm2=smf.ols(formula='Direction_bool~Lag2+I(Lag2**2)', data=weekly).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Direction_bool   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     3.345
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):             0.0356
# Time:                        19:02:15   Log-Likelihood:                -780.28
# No. Observations:                1089   AIC:                             1567.
# Df Residuals:                    1086   BIC:                             1582.
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept        0.5478      0.016     34.048      0.000         0.516     0.579
# Lag2             0.0161      0.006      2.506      0.012         0.003     0.029
# I(Lag2 ** 2)     0.0009      0.001      0.957      0.339        -0.001     0.003
# ==============================================================================
# Omnibus:                        8.652   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):              177.501
# Skew:                          -0.219   Prob(JB):                     2.86e-39
# Kurtosis:                       1.071   Cond. No.                         17.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Hacemos una regresión cúbica con lag2
lm2=smf.ols(formula='Direction_bool~Lag2+I(Lag2**2)+I(Lag2**3)', data=weekly).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Direction_bool   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.403
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):             0.0661
# Time:                        19:05:09   Log-Likelihood:                -780.02
# No. Observations:                1089   AIC:                             1568.
# Df Residuals:                    1085   BIC:                             1588.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept        0.5461      0.016     33.542      0.000         0.514     0.578
# Lag2             0.0131      0.008      1.710      0.088        -0.002     0.028
# I(Lag2 ** 2)     0.0014      0.001      1.195      0.233        -0.001     0.004
# I(Lag2 ** 3)  7.089e-05   9.81e-05      0.723      0.470        -0.000     0.000
# ==============================================================================
# Omnibus:                        8.623   Durbin-Watson:                   2.137
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):              177.497
# Skew:                          -0.219   Prob(JB):                     2.86e-39
# Kurtosis:                       1.071   Cond. No.                         231.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Hacemos una regresión cúbica con volume
lm2=smf.ols(formula='Direction_bool~Volume+I(Volume**2)+I(Volume**3)', data=weekly).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Direction_bool   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.3111
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):              0.817
# Time:                        19:12:29   Log-Likelihood:                -783.15
# No. Observations:                1089   AIC:                             1574.
# Df Residuals:                    1085   BIC:                             1594.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept          0.5837      0.033     17.551      0.000         0.518     0.649
# Volume            -0.0451      0.053     -0.846      0.398        -0.150     0.059
# I(Volume ** 2)     0.0131      0.019      0.703      0.482        -0.023     0.050
# I(Volume ** 3)    -0.0011      0.002     -0.613      0.540        -0.004     0.002
# ==============================================================================
# Omnibus:                        8.963   Durbin-Watson:                   2.147
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):              181.004
# Skew:                          -0.223   Prob(JB):                     4.96e-40
# Kurtosis:                       1.053   Cond. No.                         311.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Hacemos una regresión cuadrática con volume
lm2=smf.ols(formula='Direction_bool~Volume+I(Volume**2)', data=weekly).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Direction_bool   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.2789
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):              0.757
# Time:                        19:13:34   Log-Likelihood:                -783.34
# No. Observations:                1089   AIC:                             1573.
# Df Residuals:                    1086   BIC:                             1588.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept          0.5718      0.027     21.236      0.000         0.519     0.625
# Volume            -0.0170      0.027     -0.623      0.534        -0.071     0.037
# I(Volume ** 2)     0.0020      0.004      0.454      0.650        -0.007     0.011
# ==============================================================================
# Omnibus:                        8.967   Durbin-Watson:                   2.147
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):              181.245
# Skew:                          -0.223   Prob(JB):                     4.40e-40
# Kurtosis:                       1.052   Cond. No.                         28.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Hacemos una regresión multivariada con Volume y Lag3
lm2=smf.ols(formula='Direction_bool~Volume+Lag3', data=weekly).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Direction_bool   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.4948
# Date:                Sat, 02 Sep 2017   Prob (F-statistic):              0.610
# Time:                        19:14:40   Log-Likelihood:                -783.13
# No. Observations:                1089   AIC:                             1572.
# Df Residuals:                    1086   BIC:                             1587.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.5654      0.021     27.300      0.000         0.525     0.606
# Volume        -0.0058      0.009     -0.647      0.518        -0.023     0.012
# Lag3          -0.0051      0.006     -0.798      0.425        -0.018     0.007
# ==============================================================================
# Omnibus:                        8.952   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):              180.959
# Skew:                          -0.223   Prob(JB):                     5.07e-40
# Kurtosis:                       1.054   Cond. No.                         3.48
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Conclusión 1

# %% [markdown]
# No se encuentra una relación evidente entre las variables despúes de probar con diferentes modelos
